# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_style("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import ast

# %%
res_list = os.listdir("../vqc_results/train_process")

# %%
df = pd.DataFrame()
for c in res_list:
    if ".csv" in c:
        n_df = pd.read_csv("../vqc_results/train_process/" + c)
        n_df["reps"] = c.split("_")[-1][0]
        df = pd.concat([df, n_df], axis = 0).reset_index(drop =True)
#df

# %%
tot_df = df

# %%
#tot_df["reps"] = tot_df["reps"].fillna(2.0)
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.778677  0.731844    0.832612   0.748571      0.731305     0.715847
# 1   0.629341  0.577143    0.713826   0.604790      0.562738     0.551913
# 2   0.670295  0.617940    0.867203   0.788136      0.546261     0.508197
# 3   0.739597  0.683333    0.786020   0.694915      0.698352     0.672131
# 4   0.554896  0.502924    0.669052   0.540881      0.474018     0.469945
# 5   0.549052  0.491349    0.785377   0.669811      0.422053     0.387978
# 6   0.866032  0.826531    0.867684   0.775120      0.864385     0.885246
# 7   0.595679  0.538462    0.761341   0.651163      0.489227     0.459016
# 8   0.754146  0.707965    0.874582   0.769231      0.662864     0.655738
# 9   0.800518  0.739946    0.818543   0.726316      0.783270     0.754098
# 10  0.590240  0.529032    0.758964   0.645669      0.482890     0.448087
# 11  0.683582  0.660661    0.831216   0.733333      0.580482     0.601093
# 12  0.815584  0.755319    0.836218   0.735751      0.795944     0.775956
# 13  0.819499  0.780105    0.853224   0.748744      0.788340     0.814208
# 14  0.738764  0.706553    0.828346   0.738095      0.666667     0.677596
# 15  0.836201  0.751807    0.841026   0.672414      0.831432     0.852459
# 16  0.662100  0.616822    0.828571   0.717391      0.551331     0.540984
# 17  0.705611  0.688525    0.896484   0.860656      0.581749     0.573770
#
#          elapsed feature_map_type optimizer  \
# 0    3419.716416            Pauli    cobyla
# 1    3240.792426            Pauli    cobyla
# 2    2850.688327            Pauli    cobyla
# 3    7367.969940            Pauli      spsa
# 4    6963.982728            Pauli      spsa
# 5    6387.195896            Pauli      spsa
# 6    4354.364534            Pauli    cobyla
# 7    3820.332580            Pauli    cobyla
# 8    3242.661394            Pauli    cobyla
# 9    9807.247369            Pauli      spsa
# 10   8383.019291            Pauli      spsa
# 11   7170.829808            Pauli      spsa
# 12   5097.362706            Pauli    cobyla
# 13   4810.966516            Pauli    cobyla
# 14   4525.323399            Pauli    cobyla
# 15  13310.589567            Pauli      spsa
# 16  11727.016518            Pauli      spsa
# 17   9655.166543            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [1.0669595656780566, 1.3433650273290707, 1.080...        su2
# 1   [1.2363908879901804, 1.1546807045685932, 1.187...  two_local
# 2   [1.0267797674357146, 1.0179955740365412, 1.035...    n_local
# 3   [1.044050275216633, 0.9816643040204874, 0.9755...        su2
# 4   [1.1023983241611552, 1.1638425320323051, 1.063...  two_local
# 5   [1.003498363203906, 1.0289610064726569, 1.0041...    n_local
# 6   [1.0241258144675252, 1.1120859174185838, 1.058...        su2
# 7   [1.0485334173264973, 1.114662797107003, 1.0200...  two_local
# 8   [1.0017156024818121, 1.007999664372151, 1.0059...    n_local
# 9   [1.0170239431083563, 0.9860271207983549, 1.083...        su2
# 10  [1.1170849713816542, 0.9996514613251026, 1.061...  two_local
# 11  [1.022642985640403, 1.0383961878122656, 1.0249...    n_local
# 12  [1.1234369416476828, 1.1695906124391027, 1.161...        su2
# 13  [1.1465054765245728, 1.1741284930339044, 1.081...  two_local
# 14  [0.9467393363722144, 0.9593988685348378, 0.982...    n_local
# 15  [1.021567342243296, 0.9888621259071978, 0.9895...        su2
# 16  [1.088020489365607, 1.0781218033000899, 1.0891...  two_local
# 17  [1.0043232593781575, 1.0234164539561252, 1.023...    n_local
#
#     Training time Model  Max Iter reps
# 0     3419.716416   VQC       250    1
# 1     3240.792426   VQC       250    1
# 2     2850.688327   VQC       250    1
# 3     7367.969940   VQC       250    1
# 4     6963.982728   VQC       250    1
# 5     6387.195896   VQC       250    1
# 6     4354.364534   VQC       250    2
# 7     3820.332580   VQC       250    2
# 8     3242.661394   VQC       250    2
# 9     9807.247369   VQC       250    2
# 10    8383.019291   VQC       250    2
# 11    7170.829808   VQC       250    2
# 12    5097.362706   VQC       250    3
# 13    4810.966516   VQC       250    3
# 14    4525.323399   VQC       250    3
# 15   13310.589567   VQC       250    3
# 16   11727.016518   VQC       250    3
# 17    9655.166543   VQC       250    3

# %%
tot_df.sort_values("f1_test", ascending=False)
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 6   0.866032  0.826531    0.867684   0.775120      0.864385     0.885246
# 13  0.819499  0.780105    0.853224   0.748744      0.788340     0.814208
# 12  0.815584  0.755319    0.836218   0.735751      0.795944     0.775956
# 15  0.836201  0.751807    0.841026   0.672414      0.831432     0.852459
# 9   0.800518  0.739946    0.818543   0.726316      0.783270     0.754098
# 0   0.778677  0.731844    0.832612   0.748571      0.731305     0.715847
# 8   0.754146  0.707965    0.874582   0.769231      0.662864     0.655738
# 14  0.738764  0.706553    0.828346   0.738095      0.666667     0.677596
# 17  0.705611  0.688525    0.896484   0.860656      0.581749     0.573770
# 3   0.739597  0.683333    0.786020   0.694915      0.698352     0.672131
# 11  0.683582  0.660661    0.831216   0.733333      0.580482     0.601093
# 2   0.670295  0.617940    0.867203   0.788136      0.546261     0.508197
# 16  0.662100  0.616822    0.828571   0.717391      0.551331     0.540984
# 1   0.629341  0.577143    0.713826   0.604790      0.562738     0.551913
# 7   0.595679  0.538462    0.761341   0.651163      0.489227     0.459016
# 10  0.590240  0.529032    0.758964   0.645669      0.482890     0.448087
# 4   0.554896  0.502924    0.669052   0.540881      0.474018     0.469945
# 5   0.549052  0.491349    0.785377   0.669811      0.422053     0.387978
#
#          elapsed feature_map_type optimizer  \
# 6    4354.364534            Pauli    cobyla
# 13   4810.966516            Pauli    cobyla
# 12   5097.362706            Pauli    cobyla
# 15  13310.589567            Pauli      spsa
# 9    9807.247369            Pauli      spsa
# 0    3419.716416            Pauli    cobyla
# 8    3242.661394            Pauli    cobyla
# 14   4525.323399            Pauli    cobyla
# 17   9655.166543            Pauli      spsa
# 3    7367.969940            Pauli      spsa
# 11   7170.829808            Pauli      spsa
# 2    2850.688327            Pauli    cobyla
# 16  11727.016518            Pauli      spsa
# 1    3240.792426            Pauli    cobyla
# 7    3820.332580            Pauli    cobyla
# 10   8383.019291            Pauli      spsa
# 4    6963.982728            Pauli      spsa
# 5    6387.195896            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 6   [1.0241258144675252, 1.1120859174185838, 1.058...        su2
# 13  [1.1465054765245728, 1.1741284930339044, 1.081...  two_local
# 12  [1.1234369416476828, 1.1695906124391027, 1.161...        su2
# 15  [1.021567342243296, 0.9888621259071978, 0.9895...        su2
# 9   [1.0170239431083563, 0.9860271207983549, 1.083...        su2
# 0   [1.0669595656780566, 1.3433650273290707, 1.080...        su2
# 8   [1.0017156024818121, 1.007999664372151, 1.0059...    n_local
# 14  [0.9467393363722144, 0.9593988685348378, 0.982...    n_local
# 17  [1.0043232593781575, 1.0234164539561252, 1.023...    n_local
# 3   [1.044050275216633, 0.9816643040204874, 0.9755...        su2
# 11  [1.022642985640403, 1.0383961878122656, 1.0249...    n_local
# 2   [1.0267797674357146, 1.0179955740365412, 1.035...    n_local
# 16  [1.088020489365607, 1.0781218033000899, 1.0891...  two_local
# 1   [1.2363908879901804, 1.1546807045685932, 1.187...  two_local
# 7   [1.0485334173264973, 1.114662797107003, 1.0200...  two_local
# 10  [1.1170849713816542, 0.9996514613251026, 1.061...  two_local
# 4   [1.1023983241611552, 1.1638425320323051, 1.063...  two_local
# 5   [1.003498363203906, 1.0289610064726569, 1.0041...    n_local
#
#     Training time Model  Max Iter reps
# 6     4354.364534   VQC       250    2
# 13    4810.966516   VQC       250    3
# 12    5097.362706   VQC       250    3
# 15   13310.589567   VQC       250    3
# 9     9807.247369   VQC       250    2
# 0     3419.716416   VQC       250    1
# 8     3242.661394   VQC       250    2
# 14    4525.323399   VQC       250    3
# 17    9655.166543   VQC       250    3
# 3     7367.969940   VQC       250    1
# 11    7170.829808   VQC       250    2
# 2     2850.688327   VQC       250    1
# 16   11727.016518   VQC       250    3
# 1     3240.792426   VQC       250    1
# 7     3820.332580   VQC       250    2
# 10    8383.019291   VQC       250    2
# 4     6963.982728   VQC       250    1
# 5     6387.195896   VQC       250    1

# %%
tot_df["reps"] = tot_df["reps"].astype(int)

# %%
#tot_df = tot_df[tot_df["reps"] == 2].reset_index(drop=True)

# %%
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.778677  0.731844    0.832612   0.748571      0.731305     0.715847
# 1   0.629341  0.577143    0.713826   0.604790      0.562738     0.551913
# 2   0.670295  0.617940    0.867203   0.788136      0.546261     0.508197
# 3   0.739597  0.683333    0.786020   0.694915      0.698352     0.672131
# 4   0.554896  0.502924    0.669052   0.540881      0.474018     0.469945
# 5   0.549052  0.491349    0.785377   0.669811      0.422053     0.387978
# 6   0.866032  0.826531    0.867684   0.775120      0.864385     0.885246
# 7   0.595679  0.538462    0.761341   0.651163      0.489227     0.459016
# 8   0.754146  0.707965    0.874582   0.769231      0.662864     0.655738
# 9   0.800518  0.739946    0.818543   0.726316      0.783270     0.754098
# 10  0.590240  0.529032    0.758964   0.645669      0.482890     0.448087
# 11  0.683582  0.660661    0.831216   0.733333      0.580482     0.601093
# 12  0.815584  0.755319    0.836218   0.735751      0.795944     0.775956
# 13  0.819499  0.780105    0.853224   0.748744      0.788340     0.814208
# 14  0.738764  0.706553    0.828346   0.738095      0.666667     0.677596
# 15  0.836201  0.751807    0.841026   0.672414      0.831432     0.852459
# 16  0.662100  0.616822    0.828571   0.717391      0.551331     0.540984
# 17  0.705611  0.688525    0.896484   0.860656      0.581749     0.573770
#
#          elapsed feature_map_type optimizer  \
# 0    3419.716416            Pauli    cobyla
# 1    3240.792426            Pauli    cobyla
# 2    2850.688327            Pauli    cobyla
# 3    7367.969940            Pauli      spsa
# 4    6963.982728            Pauli      spsa
# 5    6387.195896            Pauli      spsa
# 6    4354.364534            Pauli    cobyla
# 7    3820.332580            Pauli    cobyla
# 8    3242.661394            Pauli    cobyla
# 9    9807.247369            Pauli      spsa
# 10   8383.019291            Pauli      spsa
# 11   7170.829808            Pauli      spsa
# 12   5097.362706            Pauli    cobyla
# 13   4810.966516            Pauli    cobyla
# 14   4525.323399            Pauli    cobyla
# 15  13310.589567            Pauli      spsa
# 16  11727.016518            Pauli      spsa
# 17   9655.166543            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [1.0669595656780566, 1.3433650273290707, 1.080...        su2
# 1   [1.2363908879901804, 1.1546807045685932, 1.187...  two_local
# 2   [1.0267797674357146, 1.0179955740365412, 1.035...    n_local
# 3   [1.044050275216633, 0.9816643040204874, 0.9755...        su2
# 4   [1.1023983241611552, 1.1638425320323051, 1.063...  two_local
# 5   [1.003498363203906, 1.0289610064726569, 1.0041...    n_local
# 6   [1.0241258144675252, 1.1120859174185838, 1.058...        su2
# 7   [1.0485334173264973, 1.114662797107003, 1.0200...  two_local
# 8   [1.0017156024818121, 1.007999664372151, 1.0059...    n_local
# 9   [1.0170239431083563, 0.9860271207983549, 1.083...        su2
# 10  [1.1170849713816542, 0.9996514613251026, 1.061...  two_local
# 11  [1.022642985640403, 1.0383961878122656, 1.0249...    n_local
# 12  [1.1234369416476828, 1.1695906124391027, 1.161...        su2
# 13  [1.1465054765245728, 1.1741284930339044, 1.081...  two_local
# 14  [0.9467393363722144, 0.9593988685348378, 0.982...    n_local
# 15  [1.021567342243296, 0.9888621259071978, 0.9895...        su2
# 16  [1.088020489365607, 1.0781218033000899, 1.0891...  two_local
# 17  [1.0043232593781575, 1.0234164539561252, 1.023...    n_local
#
#     Training time Model  Max Iter  reps
# 0     3419.716416   VQC       250     1
# 1     3240.792426   VQC       250     1
# 2     2850.688327   VQC       250     1
# 3     7367.969940   VQC       250     1
# 4     6963.982728   VQC       250     1
# 5     6387.195896   VQC       250     1
# 6     4354.364534   VQC       250     2
# 7     3820.332580   VQC       250     2
# 8     3242.661394   VQC       250     2
# 9     9807.247369   VQC       250     2
# 10    8383.019291   VQC       250     2
# 11    7170.829808   VQC       250     2
# 12    5097.362706   VQC       250     3
# 13    4810.966516   VQC       250     3
# 14    4525.323399   VQC       250     3
# 15   13310.589567   VQC       250     3
# 16   11727.016518   VQC       250     3
# 17    9655.166543   VQC       250     3

# %%
n = []
#n.append(ast.literal_eval(tot_df.loc[0, "objective_vals"]))
#n
ansatz_list = list(tot_df["Ansatz"].unique())
optim_list = list(tot_df["optimizer"].unique())
ansatz_list, optim_list
# Out:
# (['su2', 'two_local', 'n_local'], ['cobyla', 'spsa'])

# %% [markdown]
# ### Loss Analysis

# %%
def loss_eda(feat_map, rep, col="blue"):
    new = tot_df[tot_df["reps"] == rep].reset_index(drop=True)
    data = new[new["feature_map_type"] == feat_map].reset_index(drop=True)
    fig, axes = plt.subplots(nrows=len(ansatz_list), ncols=len(optim_list), figsize = (24, 16))
    for i in range(len(ansatz_list)):
        for j in range(len(optim_list)):
            use_data = data[(data["Ansatz"] == ansatz_list[i]) & (data["optimizer"] == optim_list[j])].reset_index(drop=True)
            loss_val = ast.literal_eval(use_data.loc[0,"objective_vals"])
            #print(loss_val)
            sns.lineplot(x = range(len(loss_val)), y = loss_val, ax = axes[i,j], color=col)
            ax = axes[i,j]
            ax.set_ylabel("loss", fontsize=10)
            ax.set_xlabel("iteration", fontsize=10)
            ax.set_title("Loss plot using %s and %s for %d reps"%(ansatz_list[i], optim_list[j], rep))

# %%
loss_eda("Pauli", 1, "red")

# %%
loss_eda("Pauli", 2, "blue")

# %%
loss_eda("Pauli", 3, "purple")

# %% [markdown]
# ## Univariate Analysis

# %%
def box_relation(cat, num, rep):
    new = tot_df[tot_df["reps"] == rep].reset_index(drop=True)
    plt.figure(figsize=(15,8))
    sns.boxplot(x=cat, y = num, data = new)
    plt.xlabel(cat)
    plt.ylabel(num)
    plt.title("Distribution of %s across %s for %d reps"%(num, cat, rep))
    plt.show();

# %%
box_relation("Ansatz", "Training time", 1)
box_relation("Ansatz", "Training time", 2)
box_relation("Ansatz", "Training time", 3)

# %%
box_relation("Ansatz", "f1_test", 1)
box_relation("Ansatz", "f1_test", 2)
box_relation("Ansatz", "f1_test", 3)

# %%
#box_relation("optimizer", "Training time")
box_relation("optimizer", "Training time", 1)
box_relation("optimizer", "Training time", 2)
box_relation("optimizer", "Training time", 3)

# %%
box_relation("optimizer", "f1_test", 1)
box_relation("optimizer", "f1_test", 2)
box_relation("optimizer", "f1_test", 3)

# %% [markdown]
# ## Multivariate Analysis

# %%
def conf_mat_create(feat_map, var1, var2, num, rep):
    use_df = tot_df[tot_df["feature_map_type"]==feat_map]
    use_df = use_df[use_df["reps"] == rep].reset_index(drop=True)
    use_df = use_df[[var1, var2, num]]
    pivot_df = use_df.pivot_table(index = [var1], columns = var2, values=num)
    plt.figure(figsize=(15,10))
    sns.heatmap(pivot_df, annot=True, fmt=".2f", linewidths=.5, cmap="RdBu")
    plt.title("%s across different %s and %s combos for %s feature map using %d reps"%(num, var1, var2, feat_map, rep))
    #return pivot_df

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 1)
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 2)
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 3)

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 1)
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 2)
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 3)

# %%
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.778677  0.731844    0.832612   0.748571      0.731305     0.715847
# 1   0.629341  0.577143    0.713826   0.604790      0.562738     0.551913
# 2   0.670295  0.617940    0.867203   0.788136      0.546261     0.508197
# 3   0.739597  0.683333    0.786020   0.694915      0.698352     0.672131
# 4   0.554896  0.502924    0.669052   0.540881      0.474018     0.469945
# 5   0.549052  0.491349    0.785377   0.669811      0.422053     0.387978
# 6   0.866032  0.826531    0.867684   0.775120      0.864385     0.885246
# 7   0.595679  0.538462    0.761341   0.651163      0.489227     0.459016
# 8   0.754146  0.707965    0.874582   0.769231      0.662864     0.655738
# 9   0.800518  0.739946    0.818543   0.726316      0.783270     0.754098
# 10  0.590240  0.529032    0.758964   0.645669      0.482890     0.448087
# 11  0.683582  0.660661    0.831216   0.733333      0.580482     0.601093
# 12  0.815584  0.755319    0.836218   0.735751      0.795944     0.775956
# 13  0.819499  0.780105    0.853224   0.748744      0.788340     0.814208
# 14  0.738764  0.706553    0.828346   0.738095      0.666667     0.677596
# 15  0.836201  0.751807    0.841026   0.672414      0.831432     0.852459
# 16  0.662100  0.616822    0.828571   0.717391      0.551331     0.540984
# 17  0.705611  0.688525    0.896484   0.860656      0.581749     0.573770
#
#          elapsed feature_map_type optimizer  \
# 0    3419.716416            Pauli    cobyla
# 1    3240.792426            Pauli    cobyla
# 2    2850.688327            Pauli    cobyla
# 3    7367.969940            Pauli      spsa
# 4    6963.982728            Pauli      spsa
# 5    6387.195896            Pauli      spsa
# 6    4354.364534            Pauli    cobyla
# 7    3820.332580            Pauli    cobyla
# 8    3242.661394            Pauli    cobyla
# 9    9807.247369            Pauli      spsa
# 10   8383.019291            Pauli      spsa
# 11   7170.829808            Pauli      spsa
# 12   5097.362706            Pauli    cobyla
# 13   4810.966516            Pauli    cobyla
# 14   4525.323399            Pauli    cobyla
# 15  13310.589567            Pauli      spsa
# 16  11727.016518            Pauli      spsa
# 17   9655.166543            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [1.0669595656780566, 1.3433650273290707, 1.080...        su2
# 1   [1.2363908879901804, 1.1546807045685932, 1.187...  two_local
# 2   [1.0267797674357146, 1.0179955740365412, 1.035...    n_local
# 3   [1.044050275216633, 0.9816643040204874, 0.9755...        su2
# 4   [1.1023983241611552, 1.1638425320323051, 1.063...  two_local
# 5   [1.003498363203906, 1.0289610064726569, 1.0041...    n_local
# 6   [1.0241258144675252, 1.1120859174185838, 1.058...        su2
# 7   [1.0485334173264973, 1.114662797107003, 1.0200...  two_local
# 8   [1.0017156024818121, 1.007999664372151, 1.0059...    n_local
# 9   [1.0170239431083563, 0.9860271207983549, 1.083...        su2
# 10  [1.1170849713816542, 0.9996514613251026, 1.061...  two_local
# 11  [1.022642985640403, 1.0383961878122656, 1.0249...    n_local
# 12  [1.1234369416476828, 1.1695906124391027, 1.161...        su2
# 13  [1.1465054765245728, 1.1741284930339044, 1.081...  two_local
# 14  [0.9467393363722144, 0.9593988685348378, 0.982...    n_local
# 15  [1.021567342243296, 0.9888621259071978, 0.9895...        su2
# 16  [1.088020489365607, 1.0781218033000899, 1.0891...  two_local
# 17  [1.0043232593781575, 1.0234164539561252, 1.023...    n_local
#
#     Training time Model  Max Iter  reps
# 0     3419.716416   VQC       250     1
# 1     3240.792426   VQC       250     1
# 2     2850.688327   VQC       250     1
# 3     7367.969940   VQC       250     1
# 4     6963.982728   VQC       250     1
# 5     6387.195896   VQC       250     1
# 6     4354.364534   VQC       250     2
# 7     3820.332580   VQC       250     2
# 8     3242.661394   VQC       250     2
# 9     9807.247369   VQC       250     2
# 10    8383.019291   VQC       250     2
# 11    7170.829808   VQC       250     2
# 12    5097.362706   VQC       250     3
# 13    4810.966516   VQC       250     3
# 14    4525.323399   VQC       250     3
# 15   13310.589567   VQC       250     3
# 16   11727.016518   VQC       250     3
# 17    9655.166543   VQC       250     3

# %%
plt.figure(figsize=(13,7))
best = tot_df[(tot_df["optimizer"]=="cobyla") & (tot_df["Ansatz"] == "su2") & (tot_df["reps"] == 2)]
sns.scatterplot(x = "Training time", y = "f1_test", data=tot_df, color= "blue")
sns.scatterplot(x = "Training time", y = "f1_test", data = best, color = "red")
plt.xlabel("Training time")
plt.ylabel("F1 score")
plt.title("F1 score vs Training time")
plt.text(x = 4400, y=0.82,s = "Optimal Algo", fontdict={"fontweight":"bold"})
#plt.legend(loc="best", )
plt.show();
