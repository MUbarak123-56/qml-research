# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_style("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import ast

# %%
res_list = os.listdir("../vqc_results/train_process")

# %%
df = pd.DataFrame()
for c in res_list:
    if ".csv" in c:
        n_df = pd.read_csv("../vqc_results/train_process/" + c)
        n_df["reps"] = c.split("_")[-1][0]
        df = pd.concat([df, n_df], axis = 0).reset_index(drop =True)
#df

# %%
tot_df = df

# %%
#tot_df["reps"] = tot_df["reps"].fillna(2.0)
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.647887  0.121646    0.735160   0.068273      0.579137     0.557377
# 1   0.457265  0.066914    0.563158   0.037736      0.384892     0.295082
# 2   0.585789  0.081720    0.565217   0.043728      0.607914     0.622951
# 3   0.629167  0.120000    0.747525   0.068337      0.543165     0.491803
# 4   0.458599  0.071028    0.559585   0.040084      0.388489     0.311475
# 5   0.578544  0.073394    0.618852   0.039886      0.543165     0.459016
# 6   0.657143  0.131783    0.759434   0.074725      0.579137     0.557377
# 7   0.577007  0.101480    0.726776   0.058252      0.478417     0.393443
# 8   0.635253  0.087054    0.616949   0.046707      0.654676     0.639344
# 9   0.648421  0.159624    0.781726   0.093151      0.553957     0.557377
# 10  0.543353  0.059744    0.585062   0.032710      0.507194     0.344262
# 11  0.677716  0.108753    0.694340   0.059163      0.661871     0.672131
# 12  0.671756  0.124054    0.715447   0.068333      0.633094     0.672131
# 13  0.685271  0.088696    0.602180   0.046832      0.794964     0.836066
# 14  0.631373  0.117647    0.693966   0.065543      0.579137     0.573770
# 15  0.726957  0.118863    0.703704   0.064516      0.751799     0.754098
# 16  0.715503  0.097996    0.679612   0.052569      0.755396     0.721311
# 17  0.678508  0.083333    0.670175   0.044929      0.687050     0.573770
#
#         elapsed feature_map_type optimizer  \
# 0   1679.475580            Pauli    cobyla
# 1   1560.234229            Pauli    cobyla
# 2   1445.376304            Pauli    cobyla
# 3   3767.527403            Pauli      spsa
# 4   3563.572480            Pauli      spsa
# 5   3310.405442            Pauli      spsa
# 6   2296.751348            Pauli    cobyla
# 7   2036.421517            Pauli    cobyla
# 8   1788.936479            Pauli    cobyla
# 9   4218.756788            Pauli      spsa
# 10  3321.338168            Pauli      spsa
# 11  2985.037140            Pauli      spsa
# 12  2075.512755            Pauli    cobyla
# 13  1774.790434            Pauli    cobyla
# 14  1508.374286            Pauli    cobyla
# 15  4476.214997            Pauli      spsa
# 16  3796.944324            Pauli      spsa
# 17  3266.013241            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [1.0032614220135616, 1.029062700280531, 1.0219...        su2
# 1   [1.0271320652510978, 1.041156129996072, 1.0070...  two_local
# 2   [1.002569180908098, 0.9965437764305586, 0.9997...    n_local
# 3   [1.0171390945904895, 1.0402324726715635, 1.030...        su2
# 4   [1.0299264670932196, 1.032375432520019, 1.0433...  two_local
# 5   [0.9991217623238456, 0.9994527695904762, 0.998...    n_local
# 6   [1.0042737479779091, 1.0400596205180126, 1.006...        su2
# 7   [1.0164499426631912, 1.0269813665877423, 1.012...  two_local
# 8   [0.9972645520479336, 0.9986102198218503, 0.998...    n_local
# 9   [1.0188084155950745, 1.0042282910870919, 1.018...        su2
# 10  [1.0123295874932283, 1.020217552280876, 1.0181...  two_local
# 11  [0.9980086609394203, 1.001240737480835, 1.0025...    n_local
# 12  [1.0255116694194086, 1.0418217295468837, 1.023...        su2
# 13  [1.0325847285032368, 1.042600411181751, 1.0357...  two_local
# 14  [0.9975929912060049, 1.0051786683306432, 0.999...    n_local
# 15  [1.0079834766348117, 1.0025693728835436, 1.007...        su2
# 16  [1.0142273598568339, 1.034428602171022, 1.0267...  two_local
# 17  [0.9977473878762113, 1.014488706939114, 1.0063...    n_local
#
#     Training time Model  Max Iter reps
# 0     1679.475580   VQC       250    1
# 1     1560.234229   VQC       250    1
# 2     1445.376304   VQC       250    1
# 3     3767.527403   VQC       250    1
# 4     3563.572480   VQC       250    1
# 5     3310.405442   VQC       250    1
# 6     2296.751348   VQC       250    2
# 7     2036.421517   VQC       250    2
# 8     1788.936479   VQC       250    2
# 9     4218.756788   VQC       250    2
# 10    3321.338168   VQC       250    2
# 11    2985.037140   VQC       250    2
# 12    2075.512755   VQC       250    3
# 13    1774.790434   VQC       250    3
# 14    1508.374286   VQC       250    3
# 15    4476.214997   VQC       250    3
# 16    3796.944324   VQC       250    3
# 17    3266.013241   VQC       250    3

# %%
tot_df.sort_values("f1_test", ascending=False)
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 9   0.648421  0.159624    0.781726   0.093151      0.553957     0.557377
# 6   0.657143  0.131783    0.759434   0.074725      0.579137     0.557377
# 12  0.671756  0.124054    0.715447   0.068333      0.633094     0.672131
# 0   0.647887  0.121646    0.735160   0.068273      0.579137     0.557377
# 3   0.629167  0.120000    0.747525   0.068337      0.543165     0.491803
# 15  0.726957  0.118863    0.703704   0.064516      0.751799     0.754098
# 14  0.631373  0.117647    0.693966   0.065543      0.579137     0.573770
# 11  0.677716  0.108753    0.694340   0.059163      0.661871     0.672131
# 7   0.577007  0.101480    0.726776   0.058252      0.478417     0.393443
# 16  0.715503  0.097996    0.679612   0.052569      0.755396     0.721311
# 13  0.685271  0.088696    0.602180   0.046832      0.794964     0.836066
# 8   0.635253  0.087054    0.616949   0.046707      0.654676     0.639344
# 17  0.678508  0.083333    0.670175   0.044929      0.687050     0.573770
# 2   0.585789  0.081720    0.565217   0.043728      0.607914     0.622951
# 5   0.578544  0.073394    0.618852   0.039886      0.543165     0.459016
# 4   0.458599  0.071028    0.559585   0.040084      0.388489     0.311475
# 1   0.457265  0.066914    0.563158   0.037736      0.384892     0.295082
# 10  0.543353  0.059744    0.585062   0.032710      0.507194     0.344262
#
#         elapsed feature_map_type optimizer  \
# 9   4218.756788            Pauli      spsa
# 6   2296.751348            Pauli    cobyla
# 12  2075.512755            Pauli    cobyla
# 0   1679.475580            Pauli    cobyla
# 3   3767.527403            Pauli      spsa
# 15  4476.214997            Pauli      spsa
# 14  1508.374286            Pauli    cobyla
# 11  2985.037140            Pauli      spsa
# 7   2036.421517            Pauli    cobyla
# 16  3796.944324            Pauli      spsa
# 13  1774.790434            Pauli    cobyla
# 8   1788.936479            Pauli    cobyla
# 17  3266.013241            Pauli      spsa
# 2   1445.376304            Pauli    cobyla
# 5   3310.405442            Pauli      spsa
# 4   3563.572480            Pauli      spsa
# 1   1560.234229            Pauli    cobyla
# 10  3321.338168            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 9   [1.0188084155950745, 1.0042282910870919, 1.018...        su2
# 6   [1.0042737479779091, 1.0400596205180126, 1.006...        su2
# 12  [1.0255116694194086, 1.0418217295468837, 1.023...        su2
# 0   [1.0032614220135616, 1.029062700280531, 1.0219...        su2
# 3   [1.0171390945904895, 1.0402324726715635, 1.030...        su2
# 15  [1.0079834766348117, 1.0025693728835436, 1.007...        su2
# 14  [0.9975929912060049, 1.0051786683306432, 0.999...    n_local
# 11  [0.9980086609394203, 1.001240737480835, 1.0025...    n_local
# 7   [1.0164499426631912, 1.0269813665877423, 1.012...  two_local
# 16  [1.0142273598568339, 1.034428602171022, 1.0267...  two_local
# 13  [1.0325847285032368, 1.042600411181751, 1.0357...  two_local
# 8   [0.9972645520479336, 0.9986102198218503, 0.998...    n_local
# 17  [0.9977473878762113, 1.014488706939114, 1.0063...    n_local
# 2   [1.002569180908098, 0.9965437764305586, 0.9997...    n_local
# 5   [0.9991217623238456, 0.9994527695904762, 0.998...    n_local
# 4   [1.0299264670932196, 1.032375432520019, 1.0433...  two_local
# 1   [1.0271320652510978, 1.041156129996072, 1.0070...  two_local
# 10  [1.0123295874932283, 1.020217552280876, 1.0181...  two_local
#
#     Training time Model  Max Iter reps
# 9     4218.756788   VQC       250    2
# 6     2296.751348   VQC       250    2
# 12    2075.512755   VQC       250    3
# 0     1679.475580   VQC       250    1
# 3     3767.527403   VQC       250    1
# 15    4476.214997   VQC       250    3
# 14    1508.374286   VQC       250    3
# 11    2985.037140   VQC       250    2
# 7     2036.421517   VQC       250    2
# 16    3796.944324   VQC       250    3
# 13    1774.790434   VQC       250    3
# 8     1788.936479   VQC       250    2
# 17    3266.013241   VQC       250    3
# 2     1445.376304   VQC       250    1
# 5     3310.405442   VQC       250    1
# 4     3563.572480   VQC       250    1
# 1     1560.234229   VQC       250    1
# 10    3321.338168   VQC       250    2

# %%
tot_df["reps"] = tot_df["reps"].astype(int)

# %%
#tot_df = tot_df[tot_df["reps"] == 2].reset_index(drop=True)

# %%
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.647887  0.121646    0.735160   0.068273      0.579137     0.557377
# 1   0.457265  0.066914    0.563158   0.037736      0.384892     0.295082
# 2   0.585789  0.081720    0.565217   0.043728      0.607914     0.622951
# 3   0.629167  0.120000    0.747525   0.068337      0.543165     0.491803
# 4   0.458599  0.071028    0.559585   0.040084      0.388489     0.311475
# 5   0.578544  0.073394    0.618852   0.039886      0.543165     0.459016
# 6   0.657143  0.131783    0.759434   0.074725      0.579137     0.557377
# 7   0.577007  0.101480    0.726776   0.058252      0.478417     0.393443
# 8   0.635253  0.087054    0.616949   0.046707      0.654676     0.639344
# 9   0.648421  0.159624    0.781726   0.093151      0.553957     0.557377
# 10  0.543353  0.059744    0.585062   0.032710      0.507194     0.344262
# 11  0.677716  0.108753    0.694340   0.059163      0.661871     0.672131
# 12  0.671756  0.124054    0.715447   0.068333      0.633094     0.672131
# 13  0.685271  0.088696    0.602180   0.046832      0.794964     0.836066
# 14  0.631373  0.117647    0.693966   0.065543      0.579137     0.573770
# 15  0.726957  0.118863    0.703704   0.064516      0.751799     0.754098
# 16  0.715503  0.097996    0.679612   0.052569      0.755396     0.721311
# 17  0.678508  0.083333    0.670175   0.044929      0.687050     0.573770
#
#         elapsed feature_map_type optimizer  \
# 0   1679.475580            Pauli    cobyla
# 1   1560.234229            Pauli    cobyla
# 2   1445.376304            Pauli    cobyla
# 3   3767.527403            Pauli      spsa
# 4   3563.572480            Pauli      spsa
# 5   3310.405442            Pauli      spsa
# 6   2296.751348            Pauli    cobyla
# 7   2036.421517            Pauli    cobyla
# 8   1788.936479            Pauli    cobyla
# 9   4218.756788            Pauli      spsa
# 10  3321.338168            Pauli      spsa
# 11  2985.037140            Pauli      spsa
# 12  2075.512755            Pauli    cobyla
# 13  1774.790434            Pauli    cobyla
# 14  1508.374286            Pauli    cobyla
# 15  4476.214997            Pauli      spsa
# 16  3796.944324            Pauli      spsa
# 17  3266.013241            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [1.0032614220135616, 1.029062700280531, 1.0219...        su2
# 1   [1.0271320652510978, 1.041156129996072, 1.0070...  two_local
# 2   [1.002569180908098, 0.9965437764305586, 0.9997...    n_local
# 3   [1.0171390945904895, 1.0402324726715635, 1.030...        su2
# 4   [1.0299264670932196, 1.032375432520019, 1.0433...  two_local
# 5   [0.9991217623238456, 0.9994527695904762, 0.998...    n_local
# 6   [1.0042737479779091, 1.0400596205180126, 1.006...        su2
# 7   [1.0164499426631912, 1.0269813665877423, 1.012...  two_local
# 8   [0.9972645520479336, 0.9986102198218503, 0.998...    n_local
# 9   [1.0188084155950745, 1.0042282910870919, 1.018...        su2
# 10  [1.0123295874932283, 1.020217552280876, 1.0181...  two_local
# 11  [0.9980086609394203, 1.001240737480835, 1.0025...    n_local
# 12  [1.0255116694194086, 1.0418217295468837, 1.023...        su2
# 13  [1.0325847285032368, 1.042600411181751, 1.0357...  two_local
# 14  [0.9975929912060049, 1.0051786683306432, 0.999...    n_local
# 15  [1.0079834766348117, 1.0025693728835436, 1.007...        su2
# 16  [1.0142273598568339, 1.034428602171022, 1.0267...  two_local
# 17  [0.9977473878762113, 1.014488706939114, 1.0063...    n_local
#
#     Training time Model  Max Iter  reps
# 0     1679.475580   VQC       250     1
# 1     1560.234229   VQC       250     1
# 2     1445.376304   VQC       250     1
# 3     3767.527403   VQC       250     1
# 4     3563.572480   VQC       250     1
# 5     3310.405442   VQC       250     1
# 6     2296.751348   VQC       250     2
# 7     2036.421517   VQC       250     2
# 8     1788.936479   VQC       250     2
# 9     4218.756788   VQC       250     2
# 10    3321.338168   VQC       250     2
# 11    2985.037140   VQC       250     2
# 12    2075.512755   VQC       250     3
# 13    1774.790434   VQC       250     3
# 14    1508.374286   VQC       250     3
# 15    4476.214997   VQC       250     3
# 16    3796.944324   VQC       250     3
# 17    3266.013241   VQC       250     3

# %%
n = []
#n.append(ast.literal_eval(tot_df.loc[0, "objective_vals"]))
#n
ansatz_list = list(tot_df["Ansatz"].unique())
optim_list = list(tot_df["optimizer"].unique())
ansatz_list, optim_list
# Out:
# (['su2', 'two_local', 'n_local'], ['cobyla', 'spsa'])

# %% [markdown]
# ### Loss Analysis

# %%
def loss_eda(feat_map, rep, col="blue"):
    new = tot_df[tot_df["reps"] == rep].reset_index(drop=True)
    data = new[new["feature_map_type"] == feat_map].reset_index(drop=True)
    fig, axes = plt.subplots(nrows=len(ansatz_list), ncols=len(optim_list), figsize = (24, 16))
    for i in range(len(ansatz_list)):
        for j in range(len(optim_list)):
            use_data = data[(data["Ansatz"] == ansatz_list[i]) & (data["optimizer"] == optim_list[j])].reset_index(drop=True)
            loss_val = ast.literal_eval(use_data.loc[0,"objective_vals"])
            #print(loss_val)
            sns.lineplot(x = range(len(loss_val)), y = loss_val, ax = axes[i,j], color=col)
            ax = axes[i,j]
            ax.set_ylabel("loss", fontsize=10)
            ax.set_xlabel("iteration", fontsize=10)
            ax.set_title("Loss plot using %s and %s for %d reps"%(ansatz_list[i], optim_list[j], rep))

# %%
loss_eda("Pauli", 1, "red")

# %%
loss_eda("Pauli", 2, "blue")

# %%
loss_eda("Pauli", 3, "purple")

# %% [markdown]
# ## Univariate Analysis

# %%
def box_relation(cat, num, rep):
    new = tot_df[tot_df["reps"] == rep].reset_index(drop=True)
    plt.figure(figsize=(15,8))
    sns.boxplot(x=cat, y = num, data = new)
    plt.xlabel(cat)
    plt.ylabel(num)
    plt.title("Distribution of %s across %s for %d reps"%(num, cat, rep))
    plt.show();

# %%
box_relation("Ansatz", "Training time", 1)
box_relation("Ansatz", "Training time", 2)
box_relation("Ansatz", "Training time", 3)

# %%
box_relation("Ansatz", "f1_test", 1)
box_relation("Ansatz", "f1_test", 2)
box_relation("Ansatz", "f1_test", 3)

# %%
#box_relation("optimizer", "Training time")
box_relation("optimizer", "Training time", 1)
box_relation("optimizer", "Training time", 2)
box_relation("optimizer", "Training time", 3)

# %%
box_relation("optimizer", "f1_test", 1)
box_relation("optimizer", "f1_test", 2)
box_relation("optimizer", "f1_test", 3)

# %% [markdown]
# ## Multivariate Analysis

# %%
def conf_mat_create(feat_map, var1, var2, num, rep):
    use_df = tot_df[tot_df["feature_map_type"]==feat_map]
    use_df = use_df[use_df["reps"] == rep].reset_index(drop=True)
    use_df = use_df[[var1, var2, num]]
    pivot_df = use_df.pivot_table(index = [var1], columns = var2, values=num)
    plt.figure(figsize=(15,10))
    sns.heatmap(pivot_df, annot=True, fmt=".2f", linewidths=.5, cmap="RdBu")
    plt.title("%s across different %s and %s combos for %s feature map using %d reps"%(num, var1, var2, feat_map, rep))
    #return pivot_df

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 1)
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 2)
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 3)

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 1)
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 2)
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 3)

# %%
plt.figure(figsize=(13,7))
best = tot_df[(tot_df["optimizer"]=="spsa") & (tot_df["Ansatz"] == "su2") & (tot_df["reps"] == 2)]
sns.scatterplot(x = "Training time", y = "f1_test", data=tot_df, color= "blue")
sns.scatterplot(x = "Training time", y = "f1_test", data = best, color = "red")
plt.xlabel("Training time")
plt.ylabel("F1 score")
plt.title("F1 score vs Training time")
plt.text(x = 4200, y=0.155,s = "Optimal Algo", fontdict={"fontweight":"bold"})
#plt.legend(loc="best", )
plt.show();
