# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_style("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import ast

# %%
res_list = os.listdir("../vqc_results/train_process")

# %%
df = pd.DataFrame()
for c in res_list:
    if ".csv" in c:
        n_df = pd.read_csv("../vqc_results/train_process/" + c)
        n_df["reps"] = c.split("_")[-1][0]
        df = pd.concat([df, n_df], axis = 0).reset_index(drop =True)
#df

# %%
tot_df = df

# %%
#tot_df["reps"] = tot_df["reps"].fillna(2.0)
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.410774  0.372093    0.726190   0.516129      0.286385     0.290909
# 1   0.338279  0.189474    0.459677   0.225000      0.267606     0.163636
# 2   0.354037  0.320000    0.522936   0.355556      0.267606     0.290909
# 3   0.469880  0.340000    0.655462   0.377778      0.366197     0.309091
# 4   0.341317  0.226804    0.471074   0.261905      0.267606     0.200000
# 5   0.248276  0.144578    0.467532   0.214286      0.169014     0.109091
# 6   0.391304  0.241758    0.577982   0.305556      0.295775     0.200000
# 7   0.169355  0.161290    0.600000   0.714286      0.098592     0.090909
# 8   0.261818  0.225352    0.580645   0.500000      0.169014     0.145455
# 9   0.361204  0.289157    0.627907   0.428571      0.253521     0.218182
# 10  0.165289  0.212121    0.689655   0.636364      0.093897     0.127273
# 11  0.258824  0.162162    0.785714   0.315789      0.154930     0.109091
# 12  0.367213  0.375000    0.608696   0.439024      0.262911     0.327273
# 13  0.364238  0.265060    0.617978   0.392857      0.258216     0.200000
# 14  0.103896  0.126984    0.666667   0.500000      0.056338     0.072727
# 15  0.445902  0.369565    0.739130   0.459459      0.319249     0.309091
# 16  0.275862  0.260870    0.750000   0.642857      0.169014     0.163636
# 17  0.368421  0.320988    0.615385   0.500000      0.262911     0.236364
#
#          elapsed feature_map_type optimizer  \
# 0    5102.376253            Pauli    cobyla
# 1    4549.491417            Pauli    cobyla
# 2    4226.200291            Pauli    cobyla
# 3   11150.118921            Pauli      spsa
# 4   10104.861699            Pauli      spsa
# 5    9323.873549            Pauli      spsa
# 6    6199.585587            Pauli    cobyla
# 7    5279.358559            Pauli    cobyla
# 8    4668.439650            Pauli    cobyla
# 9   13587.611812            Pauli      spsa
# 10  11622.827595            Pauli      spsa
# 11  10240.798840            Pauli      spsa
# 12   7309.573746            Pauli    cobyla
# 13   5916.789389            Pauli    cobyla
# 14   5081.529851            Pauli    cobyla
# 15  16004.904389            Pauli      spsa
# 16  13053.311717            Pauli      spsa
# 17  11327.044356            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [0.9929272638938349, 1.0094121710001411, 0.992...        su2
# 1   [1.0060467478325825, 1.0283709644365588, 1.001...  two_local
# 2   [0.9939252450053829, 1.0053523726633575, 0.995...    n_local
# 3   [1.0190841069195073, 0.995540859525438, 0.9958...        su2
# 4   [1.0400903592351352, 1.0309833189761153, 1.030...  two_local
# 5   [0.9914777141355593, 0.9995241792977647, 0.999...    n_local
# 6   [0.9984732418861562, 1.0156467853124789, 1.009...        su2
# 7   [1.026848205133443, 1.0267096108133729, 1.0264...  two_local
# 8   [0.9884475106242672, 1.0004353826356147, 0.994...    n_local
# 9   [0.9863634125695284, 1.011693301081277, 1.0037...        su2
# 10  [1.0606029096376455, 1.0386704057981326, 1.075...  two_local
# 11  [0.9902344565977278, 0.984910801907837, 0.9822...    n_local
# 12  [1.0180588516968632, 1.0229769566834535, 1.018...        su2
# 13  [1.0210089341161896, 1.014501251374829, 1.0051...  two_local
# 14  [0.9898684886945553, 1.0020280433218947, 0.994...    n_local
# 15  [0.9951840710490985, 0.9851487025470915, 0.997...        su2
# 16  [1.041143505092198, 1.0004075360836666, 1.0237...  two_local
# 17  [0.9995448728522655, 1.0021156080992735, 1.010...    n_local
#
#     Training time Model  Max Iter reps
# 0     5102.376253   VQC       250    1
# 1     4549.491417   VQC       250    1
# 2     4226.200291   VQC       250    1
# 3    11150.118921   VQC       250    1
# 4    10104.861699   VQC       250    1
# 5     9323.873549   VQC       250    1
# 6     6199.585587   VQC       250    2
# 7     5279.358559   VQC       250    2
# 8     4668.439650   VQC       250    2
# 9    13587.611812   VQC       250    2
# 10   11622.827595   VQC       250    2
# 11   10240.798840   VQC       250    2
# 12    7309.573746   VQC       250    3
# 13    5916.789389   VQC       250    3
# 14    5081.529851   VQC       250    3
# 15   16004.904389   VQC       250    3
# 16   13053.311717   VQC       250    3
# 17   11327.044356   VQC       250    3

# %%
tot_df.sort_values("f1_test", ascending=False)
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 12  0.367213  0.375000    0.608696   0.439024      0.262911     0.327273
# 0   0.410774  0.372093    0.726190   0.516129      0.286385     0.290909
# 15  0.445902  0.369565    0.739130   0.459459      0.319249     0.309091
# 3   0.469880  0.340000    0.655462   0.377778      0.366197     0.309091
# 17  0.368421  0.320988    0.615385   0.500000      0.262911     0.236364
# 2   0.354037  0.320000    0.522936   0.355556      0.267606     0.290909
# 9   0.361204  0.289157    0.627907   0.428571      0.253521     0.218182
# 13  0.364238  0.265060    0.617978   0.392857      0.258216     0.200000
# 16  0.275862  0.260870    0.750000   0.642857      0.169014     0.163636
# 6   0.391304  0.241758    0.577982   0.305556      0.295775     0.200000
# 4   0.341317  0.226804    0.471074   0.261905      0.267606     0.200000
# 8   0.261818  0.225352    0.580645   0.500000      0.169014     0.145455
# 10  0.165289  0.212121    0.689655   0.636364      0.093897     0.127273
# 1   0.338279  0.189474    0.459677   0.225000      0.267606     0.163636
# 11  0.258824  0.162162    0.785714   0.315789      0.154930     0.109091
# 7   0.169355  0.161290    0.600000   0.714286      0.098592     0.090909
# 5   0.248276  0.144578    0.467532   0.214286      0.169014     0.109091
# 14  0.103896  0.126984    0.666667   0.500000      0.056338     0.072727
#
#          elapsed feature_map_type optimizer  \
# 12   7309.573746            Pauli    cobyla
# 0    5102.376253            Pauli    cobyla
# 15  16004.904389            Pauli      spsa
# 3   11150.118921            Pauli      spsa
# 17  11327.044356            Pauli      spsa
# 2    4226.200291            Pauli    cobyla
# 9   13587.611812            Pauli      spsa
# 13   5916.789389            Pauli    cobyla
# 16  13053.311717            Pauli      spsa
# 6    6199.585587            Pauli    cobyla
# 4   10104.861699            Pauli      spsa
# 8    4668.439650            Pauli    cobyla
# 10  11622.827595            Pauli      spsa
# 1    4549.491417            Pauli    cobyla
# 11  10240.798840            Pauli      spsa
# 7    5279.358559            Pauli    cobyla
# 5    9323.873549            Pauli      spsa
# 14   5081.529851            Pauli    cobyla
#
#                                        objective_vals     Ansatz  \
# 12  [1.0180588516968632, 1.0229769566834535, 1.018...        su2
# 0   [0.9929272638938349, 1.0094121710001411, 0.992...        su2
# 15  [0.9951840710490985, 0.9851487025470915, 0.997...        su2
# 3   [1.0190841069195073, 0.995540859525438, 0.9958...        su2
# 17  [0.9995448728522655, 1.0021156080992735, 1.010...    n_local
# 2   [0.9939252450053829, 1.0053523726633575, 0.995...    n_local
# 9   [0.9863634125695284, 1.011693301081277, 1.0037...        su2
# 13  [1.0210089341161896, 1.014501251374829, 1.0051...  two_local
# 16  [1.041143505092198, 1.0004075360836666, 1.0237...  two_local
# 6   [0.9984732418861562, 1.0156467853124789, 1.009...        su2
# 4   [1.0400903592351352, 1.0309833189761153, 1.030...  two_local
# 8   [0.9884475106242672, 1.0004353826356147, 0.994...    n_local
# 10  [1.0606029096376455, 1.0386704057981326, 1.075...  two_local
# 1   [1.0060467478325825, 1.0283709644365588, 1.001...  two_local
# 11  [0.9902344565977278, 0.984910801907837, 0.9822...    n_local
# 7   [1.026848205133443, 1.0267096108133729, 1.0264...  two_local
# 5   [0.9914777141355593, 0.9995241792977647, 0.999...    n_local
# 14  [0.9898684886945553, 1.0020280433218947, 0.994...    n_local
#
#     Training time Model  Max Iter reps
# 12    7309.573746   VQC       250    3
# 0     5102.376253   VQC       250    1
# 15   16004.904389   VQC       250    3
# 3    11150.118921   VQC       250    1
# 17   11327.044356   VQC       250    3
# 2     4226.200291   VQC       250    1
# 9    13587.611812   VQC       250    2
# 13    5916.789389   VQC       250    3
# 16   13053.311717   VQC       250    3
# 6     6199.585587   VQC       250    2
# 4    10104.861699   VQC       250    1
# 8     4668.439650   VQC       250    2
# 10   11622.827595   VQC       250    2
# 1     4549.491417   VQC       250    1
# 11   10240.798840   VQC       250    2
# 7     5279.358559   VQC       250    2
# 5     9323.873549   VQC       250    1
# 14    5081.529851   VQC       250    3

# %%
tot_df["reps"] = tot_df["reps"].astype(int)

# %%
#tot_df = tot_df[tot_df["reps"] == 2].reset_index(drop=True)

# %%
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.410774  0.372093    0.726190   0.516129      0.286385     0.290909
# 1   0.338279  0.189474    0.459677   0.225000      0.267606     0.163636
# 2   0.354037  0.320000    0.522936   0.355556      0.267606     0.290909
# 3   0.469880  0.340000    0.655462   0.377778      0.366197     0.309091
# 4   0.341317  0.226804    0.471074   0.261905      0.267606     0.200000
# 5   0.248276  0.144578    0.467532   0.214286      0.169014     0.109091
# 6   0.391304  0.241758    0.577982   0.305556      0.295775     0.200000
# 7   0.169355  0.161290    0.600000   0.714286      0.098592     0.090909
# 8   0.261818  0.225352    0.580645   0.500000      0.169014     0.145455
# 9   0.361204  0.289157    0.627907   0.428571      0.253521     0.218182
# 10  0.165289  0.212121    0.689655   0.636364      0.093897     0.127273
# 11  0.258824  0.162162    0.785714   0.315789      0.154930     0.109091
# 12  0.367213  0.375000    0.608696   0.439024      0.262911     0.327273
# 13  0.364238  0.265060    0.617978   0.392857      0.258216     0.200000
# 14  0.103896  0.126984    0.666667   0.500000      0.056338     0.072727
# 15  0.445902  0.369565    0.739130   0.459459      0.319249     0.309091
# 16  0.275862  0.260870    0.750000   0.642857      0.169014     0.163636
# 17  0.368421  0.320988    0.615385   0.500000      0.262911     0.236364
#
#          elapsed feature_map_type optimizer  \
# 0    5102.376253            Pauli    cobyla
# 1    4549.491417            Pauli    cobyla
# 2    4226.200291            Pauli    cobyla
# 3   11150.118921            Pauli      spsa
# 4   10104.861699            Pauli      spsa
# 5    9323.873549            Pauli      spsa
# 6    6199.585587            Pauli    cobyla
# 7    5279.358559            Pauli    cobyla
# 8    4668.439650            Pauli    cobyla
# 9   13587.611812            Pauli      spsa
# 10  11622.827595            Pauli      spsa
# 11  10240.798840            Pauli      spsa
# 12   7309.573746            Pauli    cobyla
# 13   5916.789389            Pauli    cobyla
# 14   5081.529851            Pauli    cobyla
# 15  16004.904389            Pauli      spsa
# 16  13053.311717            Pauli      spsa
# 17  11327.044356            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [0.9929272638938349, 1.0094121710001411, 0.992...        su2
# 1   [1.0060467478325825, 1.0283709644365588, 1.001...  two_local
# 2   [0.9939252450053829, 1.0053523726633575, 0.995...    n_local
# 3   [1.0190841069195073, 0.995540859525438, 0.9958...        su2
# 4   [1.0400903592351352, 1.0309833189761153, 1.030...  two_local
# 5   [0.9914777141355593, 0.9995241792977647, 0.999...    n_local
# 6   [0.9984732418861562, 1.0156467853124789, 1.009...        su2
# 7   [1.026848205133443, 1.0267096108133729, 1.0264...  two_local
# 8   [0.9884475106242672, 1.0004353826356147, 0.994...    n_local
# 9   [0.9863634125695284, 1.011693301081277, 1.0037...        su2
# 10  [1.0606029096376455, 1.0386704057981326, 1.075...  two_local
# 11  [0.9902344565977278, 0.984910801907837, 0.9822...    n_local
# 12  [1.0180588516968632, 1.0229769566834535, 1.018...        su2
# 13  [1.0210089341161896, 1.014501251374829, 1.0051...  two_local
# 14  [0.9898684886945553, 1.0020280433218947, 0.994...    n_local
# 15  [0.9951840710490985, 0.9851487025470915, 0.997...        su2
# 16  [1.041143505092198, 1.0004075360836666, 1.0237...  two_local
# 17  [0.9995448728522655, 1.0021156080992735, 1.010...    n_local
#
#     Training time Model  Max Iter  reps
# 0     5102.376253   VQC       250     1
# 1     4549.491417   VQC       250     1
# 2     4226.200291   VQC       250     1
# 3    11150.118921   VQC       250     1
# 4    10104.861699   VQC       250     1
# 5     9323.873549   VQC       250     1
# 6     6199.585587   VQC       250     2
# 7     5279.358559   VQC       250     2
# 8     4668.439650   VQC       250     2
# 9    13587.611812   VQC       250     2
# 10   11622.827595   VQC       250     2
# 11   10240.798840   VQC       250     2
# 12    7309.573746   VQC       250     3
# 13    5916.789389   VQC       250     3
# 14    5081.529851   VQC       250     3
# 15   16004.904389   VQC       250     3
# 16   13053.311717   VQC       250     3
# 17   11327.044356   VQC       250     3

# %%
n = []
#n.append(ast.literal_eval(tot_df.loc[0, "objective_vals"]))
#n
ansatz_list = list(tot_df["Ansatz"].unique())
optim_list = list(tot_df["optimizer"].unique())
ansatz_list, optim_list
# Out:
# (['su2', 'two_local', 'n_local'], ['cobyla', 'spsa'])

# %% [markdown]
# ### Loss Analysis

# %%
def loss_eda(feat_map, rep, col="blue"):
    new = tot_df[tot_df["reps"] == rep].reset_index(drop=True)
    data = new[new["feature_map_type"] == feat_map].reset_index(drop=True)
    fig, axes = plt.subplots(nrows=len(ansatz_list), ncols=len(optim_list), figsize = (24, 16))
    for i in range(len(ansatz_list)):
        for j in range(len(optim_list)):
            use_data = data[(data["Ansatz"] == ansatz_list[i]) & (data["optimizer"] == optim_list[j])].reset_index(drop=True)
            loss_val = ast.literal_eval(use_data.loc[0,"objective_vals"])
            #print(loss_val)
            sns.lineplot(x = range(len(loss_val)), y = loss_val, ax = axes[i,j], color=col)
            ax = axes[i,j]
            ax.set_ylabel("loss", fontsize=10)
            ax.set_xlabel("iteration", fontsize=10)
            ax.set_title("Loss plot using %s and %s for %d reps"%(ansatz_list[i], optim_list[j], rep))

# %%
loss_eda("Pauli", 1, "red")

# %%
loss_eda("Pauli", 2, "blue")

# %%
loss_eda("Pauli", 3, "purple")

# %% [markdown]
# ## Univariate Analysis

# %%
def box_relation(cat, num, rep):
    new = tot_df[tot_df["reps"] == rep].reset_index(drop=True)
    plt.figure(figsize=(15,8))
    sns.boxplot(x=cat, y = num, data = new)
    plt.xlabel(cat)
    plt.ylabel(num)
    plt.title("Distribution of %s across %s for %d reps"%(num, cat, rep))
    plt.show();

# %%
box_relation("Ansatz", "Training time", 1)
box_relation("Ansatz", "Training time", 2)
box_relation("Ansatz", "Training time", 3)

# %%
box_relation("Ansatz", "f1_test", 1)
box_relation("Ansatz", "f1_test", 2)
box_relation("Ansatz", "f1_test", 3)

# %%
#box_relation("optimizer", "Training time")
box_relation("optimizer", "Training time", 1)
box_relation("optimizer", "Training time", 2)
box_relation("optimizer", "Training time", 3)

# %%
box_relation("optimizer", "f1_test", 1)
box_relation("optimizer", "f1_test", 2)
box_relation("optimizer", "f1_test", 3)

# %% [markdown]
# ## Multivariate Analysis

# %%
def conf_mat_create(feat_map, var1, var2, num, rep):
    use_df = tot_df[tot_df["feature_map_type"]==feat_map]
    use_df = use_df[use_df["reps"] == rep].reset_index(drop=True)
    use_df = use_df[[var1, var2, num]]
    pivot_df = use_df.pivot_table(index = [var1], columns = var2, values=num)
    plt.figure(figsize=(15,10))
    sns.heatmap(pivot_df, annot=True, fmt=".2f", linewidths=.5, cmap="RdBu")
    plt.title("%s across different %s and %s combos for %s feature map using %d reps"%(num, var1, var2, feat_map, rep))
    #return pivot_df

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 1)
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 2)
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time", 3)

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 1)
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 2)
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test", 3)

# %%
plt.figure(figsize=(13,7))
best = tot_df[(tot_df["optimizer"]=="cobyla") & (tot_df["Ansatz"] == "su2") & (tot_df["reps"] == 1)]
sns.scatterplot(x = "Training time", y = "f1_test", data=tot_df, color= "blue")
sns.scatterplot(x = "Training time", y = "f1_test", data = best, color = "red")
plt.xlabel("Training time")
plt.ylabel("F1 score")
plt.title("F1 score vs Training time")
plt.text(x = 4500, y=0.355,s = "Optimal Algo", fontdict={"fontweight":"bold"})
#plt.legend(loc="best", )
plt.show();
