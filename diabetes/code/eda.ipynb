# %%
import pandas as pd
import seaborn as sns; sns.set_style("darkgrid")
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import janitor
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_categorical_dtype

# %% [markdown]
# ### Mini data cleaning

# %%
train = pd.read_csv("../data/train.csv").clean_names()
#df

# %%
train
# Out:
#      pregnancy_occurence  glucose_concentration  blood_pressure  \
# 0                      2                     84               0
# 1                      9                    112              82
# 2                      1                    139              46
# 3                      0                    161              50
# 4                      6                    134              80
# ..                   ...                    ...             ...
# 609                    5                    139              64
# 610                    1                     96             122
# 611                   10                    101              86
# 612                    0                    141               0
# 613                    0                    125              96
#
#      triceps_foldness  serum_insulin   bmi  predigree_function  age  target
# 0                   0              0   0.0               0.304   21       0
# ...

# %%
train["target"].value_counts()
# Out:
# 0    401
# 1    213
# Name: target, dtype: int64

# %%
train.head()
# Out:
#    pregnancy_occurence  glucose_concentration  blood_pressure  \
# 0                    2                     84               0
# 1                    9                    112              82
# 2                    1                    139              46
# 3                    0                    161              50
# 4                    6                    134              80
#
#    triceps_foldness  serum_insulin   bmi  predigree_function  age  target
# 0                 0              0   0.0               0.304   21       0
# 1                24              0  28.2               1.282   50       1
# 2                19             83  28.7               0.654   22       0
# 3                 0              0  21.9               0.254   65       0
# 4                37            370  46.2               0.238   46       1

# %%
train.shape
# Out:
# (614, 9)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pregnancy_occurence    614 non-null    int64
#  1   glucose_concentration  614 non-null    int64
#  2   blood_pressure         614 non-null    int64
#  3   triceps_foldness       614 non-null    int64
#  4   serum_insulin          614 non-null    int64
#  5   bmi                    614 non-null    float64
#  6   predigree_function     614 non-null    float64
#  7   age                    614 non-null    int64
#  8   target                 614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB

# %% [markdown]
# ### Univariate analysis

# %%
def cat_eda(var):
    plt.figure(figsize=(15,10))
    sns.countplot(x = var, data = train, hue  = "target")
    plt.show();

# %%
#cat_eda("type")

# %%
def num_eda(var):
    plt.figure(figsize=(15,10))
    sns.kdeplot(x = var, data = train, hue  = "target")
    #plt.ylim(0, 500)
    plt.show();

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pregnancy_occurence    614 non-null    int64
#  1   glucose_concentration  614 non-null    int64
#  2   blood_pressure         614 non-null    int64
#  3   triceps_foldness       614 non-null    int64
#  4   serum_insulin          614 non-null    int64
#  5   bmi                    614 non-null    float64
#  6   predigree_function     614 non-null    float64
#  7   age                    614 non-null    int64
#  8   target                 614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB

# %%
num_eda("pregnancy_occurence")

# %%
num_eda("glucose_concentration")

# %%
num_eda("blood_pressure")

# %%
num_eda("triceps_foldness")

# %%
num_eda("serum_insulin")

# %%
num_eda("bmi")

# %%
num_eda("predigree_function")

# %%
num_eda("age")

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.figure(figsize=(40,20))
sns.pairplot(train, hue="target")
plt.show();

# %%
#cat_col = []
#num_col = []
#for col in list(train.columns):
#    if is_categorical_dtype(train[col]):
#        cat_col.append(col)
#    elif is_numeric_dtype(train[col]):
#        num_col.append(col)

# %%
#num_col, cat_col

# %%
#num_col.remove("target")
#num_col.remove("udi")

# %%
#num_col, cat_col

# %%
#def multiple_cat_num_eda(num, cat):
#    fig, axes = plt.subplots(nrows=len(num), ncols=1, figsize = (20, 40))
#    for i in range(len(num)):
#        for j in range(len(cat)):
#          #if var_list[i] != var_list[j]:
#            sns.violinplot(x = cat[j], y = num[i], data = train, hue = "target", ax = axes[i])
#            ax = axes[i]
#            ax.set_ylabel(num[i], fontsize=14)
#            ax.set_xlabel(cat[j], fontsize=14)

# %%
#multiple_cat_num_eda(num_col, cat_col)
