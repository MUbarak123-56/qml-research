# %%
import pandas as pd
import os

# %%
data_list = os.listdir("data_for_paper")

# %%
performance_df = pd.DataFrame()
for i in range(len(data_list)):
    if "performance" in data_list[i]:
        df = pd.read_csv("data_for_paper/" + data_list[i])
        performance_df = pd.concat([performance_df, df], axis = 0).reset_index(drop=True)

# %%
performance_df
# Out:
#      f1_test  f1_train  prec_train  prec_test  recall_train  recall_test  \
# 0   0.624113  0.758772    0.711934   0.511628      0.812207     0.800000
# 1   0.638655  0.698254    0.744681   0.593750      0.657277     0.690909
# 2   0.640000  0.674757    0.698492   0.571429      0.652582     0.727273
# 3   0.677165  0.917258    0.923810   0.597222      0.910798     0.781818
# 4   0.636364  0.840506    0.912088   0.636364      0.779343     0.636364
# 5   0.610169  0.779661    0.650943   0.442623      0.971831     0.981818
# 6   0.600000  0.964371    0.975962   0.494118      0.953052     0.763636
# 7   0.372093  0.410774    0.726190   0.516129      0.286385     0.290909
# 8   0.968254  0.986867    0.974074   0.938462      1.000000     1.000000
# 9   0.940874  0.965644    0.935791   0.888350      0.997465     1.000000
# 10  0.970822  0.998734    0.997472   0.943299      1.000000     1.000000
# 11  0.965699  0.986867    0.974074   0.933673      1.000000     1.000000
# 12  0.981233  0.996207    0.993695   0.963158      0.998733     1.000000
# 13  0.965699  0.986233    0.974042   0.933673      0.998733     1.000000
# 14  0.962162  0.976627    0.973552   0.951872      0.979721     0.972678
# 15  0.826531  0.866032    0.867684   0.775120      0.864385     0.885246
# 16  0.278571  0.785276    0.909953   0.178082      0.690647     0.639344
# 17  0.300283  0.940754    0.939068   0.181507      0.942446     0.868852
# 18  0.216561  0.814545    0.823529   0.124390      0.805755     0.836066
# 19  0.200000  0.832117    0.844444   0.116095      0.820144     0.721311
# 20  0.293059  0.936396    0.920139   0.173780      0.953237     0.934426
# 21  0.328267  0.914286    0.907801   0.201493      0.920863     0.885246
# 22  0.288000  0.958106    0.970480   0.171975      0.946043     0.885246
# 23  0.118863  0.726957    0.703704   0.064516      0.751799     0.754098
# 24  0.869565  0.853691    0.834646   0.816327      0.873626     0.930233
# 25  0.843931  0.881598    0.916914   0.839080      0.848901     0.848837
# 26  0.826347  0.920821    0.987421   0.851852      0.862637     0.802326
# 27  0.850575  0.860795    0.891176   0.840909      0.832418     0.860465
# 28  0.817610  0.821374    0.924399   0.890411      0.739011     0.755814
# 29  0.848837  0.916185    0.966463   0.848837      0.870879     0.848837
# 30  0.852071  0.876274    0.931889   0.867470      0.826923     0.837209
# 31  0.831325  0.823022    0.864048   0.862500      0.785714     0.802326
#
#                   model       elapsed    tau      C feature_map_type  \
# 0         Decision Tree      0.005158    0.0    0.0                0
# 1   Logistic Regression      0.010675    0.0    0.0                0
# 2           Naive Bayes      0.004743    0.0    0.0                0
# 3         Random Forest      0.092609    0.0    0.0                0
# 4                   SVC      0.163556    0.0    0.0                0
# 5          Pegasos QSVC    372.593309  300.0  200.0                0
# 6                  QSVC  10798.149189    0.0    0.0                0
# 7                   VQC   5102.376253    0.0    0.0            Pauli
# 8                  QSVC  41142.298698    0.0    0.0                0
# 9           Naive Bayes      0.005849    0.0    0.0                0
# 10        Random Forest      0.112706    0.0    0.0                0
# 11                  SVC      0.027467    0.0    0.0                0
# 12        Decision Tree      0.007999    0.0    0.0                0
# 13  Logistic Regression      0.015601    0.0    0.0                0
# 14         Pegasos QSVC     70.398480  300.0  750.0                0
# 15                  VQC   4354.364534    0.0    0.0            Pauli
# 16         Pegasos QSVC    146.039537  300.0  750.0                0
# 17        Decision Tree      0.005781    0.0    0.0                0
# 18  Logistic Regression      0.018321    0.0    0.0                0
# 19          Naive Bayes      0.005234    0.0    0.0                0
# 20        Random Forest      0.067111    0.0    0.0                0
# 21                  SVC      0.018017    0.0    0.0                0
# 22                 QSVC   1816.435473    0.0    0.0                0
# 23                  VQC   4476.214997    0.0    0.0            Pauli
# 24         Pegasos QSVC    933.720333  400.0  100.0                0
# 25                 QSVC  10124.409601    0.0    0.0                0
# 26        Decision Tree      0.008134    0.0    0.0                0
# 27  Logistic Regression      0.014716    0.0    0.0                0
# 28          Naive Bayes      0.004888    0.0    0.0                0
# 29        Random Forest      0.197358    0.0    0.0                0
# 30                  SVC      0.107552    0.0    0.0                0
# 31                  VQC   3433.498191    0.0    0.0            Pauli
#
#    optimizer                                     objective_vals Ansatz  \
# 0          0                                                  0      0
# 1          0                                                  0      0
# 2          0                                                  0      0
# 3          0                                                  0      0
# 4          0                                                  0      0
# 5          0                                                  0      0
# 6          0                                                  0      0
# 7     cobyla  [0.9929272638938349, 1.0094121710001411, 0.992...    su2
# 8          0                                                  0      0
# 9          0                                                  0      0
# 10         0                                                  0      0
# 11         0                                                  0      0
# 12         0                                                  0      0
# 13         0                                                  0      0
# 14         0                                                  0      0
# 15    cobyla  [1.0241258144675252, 1.1120859174185838, 1.058...    su2
# 16         0                                                  0      0
# 17         0                                                  0      0
# 18         0                                                  0      0
# 19         0                                                  0      0
# 20         0                                                  0      0
# 21         0                                                  0      0
# 22         0                                                  0      0
# 23      spsa  [1.0079834766348117, 1.0025693728835436, 1.007...    su2
# 24         0                                                  0      0
# 25         0                                                  0      0
# 26         0                                                  0      0
# 27         0                                                  0      0
# 28         0                                                  0      0
# 29         0                                                  0      0
# 30         0                                                  0      0
# 31    cobyla  [1.0329771903191045, 1.061389157689562, 1.0332...    su2
#
#     Training time Model  Max Iter  reps                    data
# 0        0.000000     0       0.0   0.0                diabetes
# 1        0.000000     0       0.0   0.0                diabetes
# 2        0.000000     0       0.0   0.0                diabetes
# 3        0.000000     0       0.0   0.0                diabetes
# 4        0.000000     0       0.0   0.0                diabetes
# 5        0.000000     0       0.0   0.0                diabetes
# 6        0.000000     0       0.0   0.0                diabetes
# 7     5102.376253   VQC     250.0   1.0                diabetes
# 8        0.000000     0       0.0   0.0                    room
# 9        0.000000     0       0.0   0.0                    room
# 10       0.000000     0       0.0   0.0                    room
# 11       0.000000     0       0.0   0.0                    room
# 12       0.000000     0       0.0   0.0                    room
# 13       0.000000     0       0.0   0.0                    room
# 14       0.000000     0       0.0   0.0                    room
# 15    4354.364534   VQC     250.0   2.0                    room
# 16       0.000000     0       0.0   0.0  predictive maintenance
# 17       0.000000     0       0.0   0.0  predictive maintenance
# 18       0.000000     0       0.0   0.0  predictive maintenance
# 19       0.000000     0       0.0   0.0  predictive maintenance
# 20       0.000000     0       0.0   0.0  predictive maintenance
# 21       0.000000     0       0.0   0.0  predictive maintenance
# 22       0.000000     0       0.0   0.0  predictive maintenance
# 23    4476.214997   VQC     250.0   3.0  predictive maintenance
# 24       0.000000     0       0.0   0.0                  raisin
# 25       0.000000     0       0.0   0.0                  raisin
# 26       0.000000     0       0.0   0.0                  raisin
# 27       0.000000     0       0.0   0.0                  raisin
# 28       0.000000     0       0.0   0.0                  raisin
# 29       0.000000     0       0.0   0.0                  raisin
# 30       0.000000     0       0.0   0.0                  raisin
# 31    3433.498191   VQC     250.0   2.0                  raisin

# %%
performance_df = performance_df[["f1_test", "f1_train", "prec_test", "prec_train", "recall_test", "recall_train", "model","elapsed", "data"]]

# %%
performance_df.to_csv("collected_data/performance.csv", index=False)

# %%
performance_df
# Out:
#      f1_test  f1_train  prec_test  prec_train  recall_test  recall_train  \
# 0   0.624113  0.758772   0.511628    0.711934     0.800000      0.812207
# 1   0.638655  0.698254   0.593750    0.744681     0.690909      0.657277
# 2   0.640000  0.674757   0.571429    0.698492     0.727273      0.652582
# 3   0.677165  0.917258   0.597222    0.923810     0.781818      0.910798
# 4   0.636364  0.840506   0.636364    0.912088     0.636364      0.779343
# 5   0.610169  0.779661   0.442623    0.650943     0.981818      0.971831
# 6   0.600000  0.964371   0.494118    0.975962     0.763636      0.953052
# 7   0.372093  0.410774   0.516129    0.726190     0.290909      0.286385
# 8   0.968254  0.986867   0.938462    0.974074     1.000000      1.000000
# 9   0.940874  0.965644   0.888350    0.935791     1.000000      0.997465
# 10  0.970822  0.998734   0.943299    0.997472     1.000000      1.000000
# 11  0.965699  0.986867   0.933673    0.974074     1.000000      1.000000
# 12  0.981233  0.996207   0.963158    0.993695     1.000000      0.998733
# 13  0.965699  0.986233   0.933673    0.974042     1.000000      0.998733
# 14  0.962162  0.976627   0.951872    0.973552     0.972678      0.979721
# 15  0.826531  0.866032   0.775120    0.867684     0.885246      0.864385
# 16  0.278571  0.785276   0.178082    0.909953     0.639344      0.690647
# 17  0.300283  0.940754   0.181507    0.939068     0.868852      0.942446
# 18  0.216561  0.814545   0.124390    0.823529     0.836066      0.805755
# 19  0.200000  0.832117   0.116095    0.844444     0.721311      0.820144
# 20  0.293059  0.936396   0.173780    0.920139     0.934426      0.953237
# 21  0.328267  0.914286   0.201493    0.907801     0.885246      0.920863
# 22  0.288000  0.958106   0.171975    0.970480     0.885246      0.946043
# 23  0.118863  0.726957   0.064516    0.703704     0.754098      0.751799
# 24  0.869565  0.853691   0.816327    0.834646     0.930233      0.873626
# 25  0.843931  0.881598   0.839080    0.916914     0.848837      0.848901
# 26  0.826347  0.920821   0.851852    0.987421     0.802326      0.862637
# 27  0.850575  0.860795   0.840909    0.891176     0.860465      0.832418
# 28  0.817610  0.821374   0.890411    0.924399     0.755814      0.739011
# 29  0.848837  0.916185   0.848837    0.966463     0.848837      0.870879
# 30  0.852071  0.876274   0.867470    0.931889     0.837209      0.826923
# 31  0.831325  0.823022   0.862500    0.864048     0.802326      0.785714
#
#                   model       elapsed                    data
# 0         Decision Tree      0.005158                diabetes
# 1   Logistic Regression      0.010675                diabetes
# 2           Naive Bayes      0.004743                diabetes
# 3         Random Forest      0.092609                diabetes
# 4                   SVC      0.163556                diabetes
# 5          Pegasos QSVC    372.593309                diabetes
# 6                  QSVC  10798.149189                diabetes
# 7                   VQC   5102.376253                diabetes
# 8                  QSVC  41142.298698                    room
# 9           Naive Bayes      0.005849                    room
# 10        Random Forest      0.112706                    room
# 11                  SVC      0.027467                    room
# 12        Decision Tree      0.007999                    room
# 13  Logistic Regression      0.015601                    room
# 14         Pegasos QSVC     70.398480                    room
# 15                  VQC   4354.364534                    room
# 16         Pegasos QSVC    146.039537  predictive maintenance
# 17        Decision Tree      0.005781  predictive maintenance
# 18  Logistic Regression      0.018321  predictive maintenance
# 19          Naive Bayes      0.005234  predictive maintenance
# 20        Random Forest      0.067111  predictive maintenance
# 21                  SVC      0.018017  predictive maintenance
# 22                 QSVC   1816.435473  predictive maintenance
# 23                  VQC   4476.214997  predictive maintenance
# 24         Pegasos QSVC    933.720333                  raisin
# 25                 QSVC  10124.409601                  raisin
# 26        Decision Tree      0.008134                  raisin
# 27  Logistic Regression      0.014716                  raisin
# 28          Naive Bayes      0.004888                  raisin
# 29        Random Forest      0.197358                  raisin
# 30                  SVC      0.107552                  raisin
# 31                  VQC   3433.498191                  raisin

# %%
feature_runtime_svc_df = pd.DataFrame()
for i in range(len(data_list)):
    if "feature_runtime_svc" in data_list[i]:
        df = pd.read_csv("data_for_paper/" + data_list[i])
        feature_runtime_svc_df = pd.concat([feature_runtime_svc_df, df], axis = 0).reset_index(drop=True)
feature_runtime_svc_df.to_csv("collected_data/feature_runtime_svc.csv", index=False)

# %%
feature_runtime_svc_df
# Out:
#     num_features         model      runtime      data
# 0            1.0    SVC_linear     0.021062  diabetes
# 1            2.0    SVC_linear     0.017806  diabetes
# 2            3.0    SVC_linear     0.011805  diabetes
# 3            4.0    SVC_linear     0.011664  diabetes
# 4            5.0    SVC_linear     0.011873  diabetes
# ..           ...           ...          ...       ...
# 95           3.0  Pegasos QSVC    73.319519    raisin
# 96           4.0  Pegasos QSVC   113.826523    raisin
# 97           5.0  Pegasos QSVC   174.409979    raisin
# 98           6.0  Pegasos QSVC  3217.896325    raisin
# 99           7.0  Pegasos QSVC   357.843616    raisin
#
# [100 rows x 4 columns]

# %%
size_runtime_svc_df = pd.DataFrame()
for i in range(len(data_list)):
    if "size_runtime_svc" in data_list[i]:
        df = pd.read_csv("data_for_paper/" + data_list[i])
        size_runtime_svc_df = pd.concat([size_runtime_svc_df, df], axis = 0).reset_index(drop=True)
size_runtime_svc_df.to_csv("collected_data/size_runtime_svc.csv", index=False)

# %%
size_runtime_svc_df
# Out:
#       size         model     runtime      data
# 0     49.1    SVC_linear    0.006433  diabetes
# 1     98.2    SVC_linear    0.004084  diabetes
# 2    147.3    SVC_linear    0.004067  diabetes
# 3    196.4    SVC_linear    0.005010  diabetes
# 4    245.5    SVC_linear    0.005751  diabetes
# ..     ...           ...         ...       ...
# 155  432.0  Pegasos QSVC  370.734311    raisin
# 156  504.0  Pegasos QSVC  370.877921    raisin
# 157  576.0  Pegasos QSVC  402.424679    raisin
# 158  648.0  Pegasos QSVC  376.422824    raisin
# 159  720.0  Pegasos QSVC  345.784612    raisin
#
# [160 rows x 4 columns]

# %%
feature_runtime_vqc_df = pd.DataFrame()
for i in range(len(data_list)):
    if "feature_runtime_vqc" in data_list[i]:
        df = pd.read_csv("data_for_paper/" + data_list[i])
        feature_runtime_vqc_df = pd.concat([feature_runtime_vqc_df, df], axis = 0).reset_index(drop=True)
feature_runtime_vqc_df.to_csv("collected_data/feature_runtime_vqc.csv", index=False)
feature_runtime_vqc_df
# Out:
#     num_features           model      runtime                    data
# 0            2.0  vqc_su2_cobyla   268.506765                    room
# 1            3.0  vqc_su2_cobyla   415.010232                    room
# 2            4.0  vqc_su2_cobyla   598.789714                    room
# 3            5.0  vqc_su2_cobyla  1088.712200                    room
# 4            6.0  vqc_su2_cobyla  1474.647259                    room
# 5            7.0  vqc_su2_cobyla  2011.656045                    room
# 6            2.0    vqc_su2_spsa   433.968014  predictive maintenance
# 7            3.0    vqc_su2_spsa   691.598410  predictive maintenance
# 8            4.0    vqc_su2_spsa  1056.097049  predictive maintenance
# 9            5.0    vqc_su2_spsa  1879.518390  predictive maintenance
# 10           6.0    vqc_su2_spsa  2781.881721  predictive maintenance
# 11           2.0  vqc_su2_cobyla   125.994051                diabetes
# 12           3.0  vqc_su2_cobyla   201.696050                diabetes
# 13           4.0  vqc_su2_cobyla   296.547693                diabetes
# 14           5.0  vqc_su2_cobyla   421.138425                diabetes
# 15           6.0  vqc_su2_cobyla   573.627814                diabetes
# 16           7.0  vqc_su2_cobyla   765.015378                diabetes
# 17           8.0  vqc_su2_cobyla  1025.072767                diabetes
# 18           2.0  vqc_su2_cobyla   268.506765                  raisin
# 19           3.0  vqc_su2_cobyla   415.010232                  raisin
# 20           4.0  vqc_su2_cobyla   598.789714                  raisin
# 21           5.0  vqc_su2_cobyla  1088.712200                  raisin
# 22           6.0  vqc_su2_cobyla  1474.647259                  raisin
# 23           7.0  vqc_su2_cobyla  2011.656045                  raisin

# %%
size_runtime_vqc_df = pd.DataFrame()
for i in range(len(data_list)):
    if "size_runtime_vqc" in data_list[i]:
        df = pd.read_csv("data_for_paper/" + data_list[i])
        size_runtime_vqc_df = pd.concat([size_runtime_vqc_df, df], axis = 0).reset_index(drop=True)
size_runtime_vqc_df.to_csv("collected_data/size_runtime_vqc.csv", index=False)
size_runtime_vqc_df
# Out:
#           size           model      runtime                    data
# 0    55.600000    vqc_su2_spsa   266.669117  predictive maintenance
# 1   127.085714    vqc_su2_spsa   609.161635  predictive maintenance
# 2   198.571429    vqc_su2_spsa   950.873044  predictive maintenance
# 3   270.057143    vqc_su2_spsa  1255.217131  predictive maintenance
# 4   341.542857    vqc_su2_spsa  1544.352010  predictive maintenance
# 5   413.028571    vqc_su2_spsa  1842.381005  predictive maintenance
# 6   484.514286    vqc_su2_spsa  2258.248342  predictive maintenance
# 7   556.000000    vqc_su2_spsa  2539.809587  predictive maintenance
# 8    49.100000  vqc_su2_cobyla    98.730349                diabetes
# 9   112.228571  vqc_su2_cobyla   224.966592                diabetes
# 10  175.357143  vqc_su2_cobyla   354.230841                diabetes
# 11  238.485714  vqc_su2_cobyla   475.842215                diabetes
# 12  301.614286  vqc_su2_cobyla   598.921852                diabetes
# 13  364.742857  vqc_su2_cobyla   753.230747                diabetes
# 14  427.871429  vqc_su2_cobyla   899.735106                diabetes
# 15  491.000000  vqc_su2_cobyla  1026.295579                diabetes
# 16   72.000000  vqc_su2_cobyla   204.039361                  raisin
# 17  164.571429  vqc_su2_cobyla   486.694044                  raisin
# 18  257.142857  vqc_su2_cobyla   725.582209                  raisin
# 19  349.714286  vqc_su2_cobyla   954.707713                  raisin
# 20  442.285714  vqc_su2_cobyla  1232.654887                  raisin
# 21  534.857143  vqc_su2_cobyla  1453.739812                  raisin
# 22  627.428571  vqc_su2_cobyla  1697.306501                  raisin
# 23  720.000000  vqc_su2_cobyla  2016.719855                  raisin
# 24   72.000000  vqc_su2_cobyla   204.039361                    room
# 25  164.571429  vqc_su2_cobyla   486.694044                    room
# 26  257.142857  vqc_su2_cobyla   725.582209                    room
# 27  349.714286  vqc_su2_cobyla   954.707713                    room
# 28  442.285714  vqc_su2_cobyla  1232.654887                    room
# 29  534.857143  vqc_su2_cobyla  1453.739812                    room
# 30  627.428571  vqc_su2_cobyla  1697.306501                    room
# 31  720.000000  vqc_su2_cobyla  2016.719855                    room
