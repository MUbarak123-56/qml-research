# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_style("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import ast

# %%
res_list = os.listdir("../vqc_results/train_process")

# %%
df = pd.DataFrame()
for c in res_list:
    if ".csv" in c:
        n_df = pd.read_csv("../vqc_results/train_process/" + c)
        n_df["reps"] = c.split("_")[-1][0]
        df = pd.concat([df, n_df], axis = 0).reset_index(drop =True)
#df

# %%
tot_df = df

# %%
#tot_df["reps"] = tot_df["reps"].fillna(2.0)
tot_df
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0   0.682227  0.697674    0.594608   0.603368      0.800132     0.826923
# 1   0.633230  0.630505    0.536541   0.542514      0.772427     0.752564
# 2   0.587252  0.590142    0.622140   0.623395      0.556069     0.560256
# 3   0.605924  0.598372    0.638088   0.635447      0.576847     0.565385
# 4   0.608764  0.607076    0.579214   0.588448      0.641491     0.626923
# 5   0.669736  0.665928    0.580411   0.586341      0.791557     0.770513
# 6   0.632582  0.632005    0.666545   0.667618      0.601913     0.600000
# 7   0.715596  0.720467    0.573302   0.580266      0.951847     0.950000
# 8   0.709559  0.710791    0.563287   0.567816      0.958443     0.950000
# 9   0.698590  0.711599    0.585377   0.600529      0.866095     0.873077
# 10  0.732973  0.731405    0.610222   0.612457      0.917546     0.907692
# 11  0.614426  0.620939    0.558554   0.585034      0.682718     0.661538
# 12  0.709857  0.711306    0.613554   0.621881      0.842018     0.830769
# 13  0.646476  0.646188    0.549527   0.564717      0.784960     0.755128
# 14  0.714961  0.717092    0.574170   0.581210      0.947230     0.935897
# 15  0.681551  0.686308    0.614407   0.624606      0.765172     0.761538
# 16  0.723359  0.728115    0.603171   0.608434      0.903364     0.906410
# 17  0.734345  0.732224    0.604999   0.603491      0.934037     0.930769
#
#          elapsed feature_map_type optimizer  \
# 0   10404.709974            Pauli    cobyla
# 1    9518.375556            Pauli    cobyla
# 2    9103.529367            Pauli    cobyla
# 3   27317.801680            Pauli      spsa
# 4   24858.312865            Pauli      spsa
# 5   21150.369866            Pauli      spsa
# 6   16172.243627            Pauli    cobyla
# 7   13538.573926            Pauli    cobyla
# 8   11312.101276            Pauli    cobyla
# 9   36492.329890            Pauli      spsa
# 10  32556.542017            Pauli      spsa
# 11  34408.853433            Pauli      spsa
# 12  21856.911325            Pauli    cobyla
# 13  16910.956723            Pauli    cobyla
# 14  12288.451014            Pauli    cobyla
# 15  46112.992277            Pauli      spsa
# 16  36824.305810            Pauli      spsa
# 17  31301.292890            Pauli      spsa
#
#                                        objective_vals     Ansatz  \
# 0   [0.9897740857946187, 1.0024650662119596, 0.991...        su2
# 1   [0.9972770553357487, 1.0468090905234526, 0.998...  two_local
# 2   [0.9955402778400992, 0.996378080566292, 0.9943...    n_local
# 3   [0.9882844902185404, 0.9913282965556462, 1.000...        su2
# 4   [0.9965935489175256, 1.0102135849152825, 1.000...  two_local
# 5   [0.999443064308944, 0.9987520573400221, 0.9978...    n_local
# 6   [0.9955071123141361, 0.9968499301903374, 0.995...        su2
# 7   [1.0093994267349489, 1.0097192964774158, 0.997...  two_local
# 8   [0.9866457593259174, 0.9892075741769691, 0.986...    n_local
# 9   [0.9952617117278842, 0.9921541356552587, 0.991...        su2
# 10  [1.0136491466111865, 0.9998966158707154, 0.999...  two_local
# 11  [0.999128702107861, 1.0005809021906438, 0.9978...    n_local
# 12  [0.9951585257975473, 1.0156646904287003, 0.998...        su2
# 13  [1.002604357775895, 1.0086113506336014, 1.0014...  two_local
# 14  [0.9982865909028081, 0.9957650968597632, 0.992...    n_local
# 15  [0.9950158014369246, 1.0232661480495973, 1.018...        su2
# 16  [1.0288388587919617, 1.012898966029641, 1.0261...  two_local
# 17  [0.9972766960950264, 0.9977776318899266, 1.000...    n_local
#
#     Training time Model  Max Iter reps
# 0    10404.709974   VQC       100    1
# 1     9518.375556   VQC       100    1
# 2     9103.529367   VQC       100    1
# 3    27317.801680   VQC       100    1
# 4    24858.312865   VQC       100    1
# 5    21150.369866   VQC       100    1
# 6    16172.243627   VQC       100    2
# 7    13538.573926   VQC       100    2
# 8    11312.101276   VQC       100    2
# 9    36492.329890   VQC       100    2
# 10   32556.542017   VQC       100    2
# 11   34408.853433   VQC       100    2
# 12   21856.911325   VQC       100    3
# 13   16910.956723   VQC       100    3
# 14   12288.451014   VQC       100    3
# 15   46112.992277   VQC       100    3
# 16   36824.305810   VQC       100    3
# 17   31301.292890   VQC       100    3

# %%
tot_df.sort_values("f1_test", ascending=False)
# Out:
#     f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 17  0.734345  0.732224    0.604999   0.603491      0.934037     0.930769
# 10  0.732973  0.731405    0.610222   0.612457      0.917546     0.907692
# 16  0.723359  0.728115    0.603171   0.608434      0.903364     0.906410
# 7   0.715596  0.720467    0.573302   0.580266      0.951847     0.950000
# 14  0.714961  0.717092    0.574170   0.581210      0.947230     0.935897
# 9   0.698590  0.711599    0.585377   0.600529      0.866095     0.873077
# 12  0.709857  0.711306    0.613554   0.621881      0.842018     0.830769
# 8   0.709559  0.710791    0.563287   0.567816      0.958443     0.950000
# 0   0.682227  0.697674    0.594608   0.603368      0.800132     0.826923
# 15  0.681551  0.686308    0.614407   0.624606      0.765172     0.761538
# 5   0.669736  0.665928    0.580411   0.586341      0.791557     0.770513
# 13  0.646476  0.646188    0.549527   0.564717      0.784960     0.755128
# 6   0.632582  0.632005    0.666545   0.667618      0.601913     0.600000
# 1   0.633230  0.630505    0.536541   0.542514      0.772427     0.752564
# 11  0.614426  0.620939    0.558554   0.585034      0.682718     0.661538
# 4   0.608764  0.607076    0.579214   0.588448      0.641491     0.626923
# 3   0.605924  0.598372    0.638088   0.635447      0.576847     0.565385
# 2   0.587252  0.590142    0.622140   0.623395      0.556069     0.560256
#
#          elapsed feature_map_type optimizer  \
# 17  31301.292890            Pauli      spsa
# 10  32556.542017            Pauli      spsa
# 16  36824.305810            Pauli      spsa
# 7   13538.573926            Pauli    cobyla
# 14  12288.451014            Pauli    cobyla
# 9   36492.329890            Pauli      spsa
# 12  21856.911325            Pauli    cobyla
# 8   11312.101276            Pauli    cobyla
# 0   10404.709974            Pauli    cobyla
# 15  46112.992277            Pauli      spsa
# 5   21150.369866            Pauli      spsa
# 13  16910.956723            Pauli    cobyla
# 6   16172.243627            Pauli    cobyla
# 1    9518.375556            Pauli    cobyla
# 11  34408.853433            Pauli      spsa
# 4   24858.312865            Pauli      spsa
# 3   27317.801680            Pauli      spsa
# 2    9103.529367            Pauli    cobyla
#
#                                        objective_vals     Ansatz  \
# 17  [0.9972766960950264, 0.9977776318899266, 1.000...    n_local
# 10  [1.0136491466111865, 0.9998966158707154, 0.999...  two_local
# 16  [1.0288388587919617, 1.012898966029641, 1.0261...  two_local
# 7   [1.0093994267349489, 1.0097192964774158, 0.997...  two_local
# 14  [0.9982865909028081, 0.9957650968597632, 0.992...    n_local
# 9   [0.9952617117278842, 0.9921541356552587, 0.991...        su2
# 12  [0.9951585257975473, 1.0156646904287003, 0.998...        su2
# 8   [0.9866457593259174, 0.9892075741769691, 0.986...    n_local
# 0   [0.9897740857946187, 1.0024650662119596, 0.991...        su2
# 15  [0.9950158014369246, 1.0232661480495973, 1.018...        su2
# 5   [0.999443064308944, 0.9987520573400221, 0.9978...    n_local
# 13  [1.002604357775895, 1.0086113506336014, 1.0014...  two_local
# 6   [0.9955071123141361, 0.9968499301903374, 0.995...        su2
# 1   [0.9972770553357487, 1.0468090905234526, 0.998...  two_local
# 11  [0.999128702107861, 1.0005809021906438, 0.9978...    n_local
# 4   [0.9965935489175256, 1.0102135849152825, 1.000...  two_local
# 3   [0.9882844902185404, 0.9913282965556462, 1.000...        su2
# 2   [0.9955402778400992, 0.996378080566292, 0.9943...    n_local
#
#     Training time Model  Max Iter reps
# 17   31301.292890   VQC       100    3
# 10   32556.542017   VQC       100    2
# 16   36824.305810   VQC       100    3
# 7    13538.573926   VQC       100    2
# 14   12288.451014   VQC       100    3
# 9    36492.329890   VQC       100    2
# 12   21856.911325   VQC       100    3
# 8    11312.101276   VQC       100    2
# 0    10404.709974   VQC       100    1
# 15   46112.992277   VQC       100    3
# 5    21150.369866   VQC       100    1
# 13   16910.956723   VQC       100    3
# 6    16172.243627   VQC       100    2
# 1     9518.375556   VQC       100    1
# 11   34408.853433   VQC       100    2
# 4    24858.312865   VQC       100    1
# 3    27317.801680   VQC       100    1
# 2     9103.529367   VQC       100    1

# %%
tot_df["reps"] = tot_df["reps"].astype(int)

# %%
tot_df = tot_df[tot_df["reps"] == 2].reset_index(drop=True)

# %%
tot_df
# Out:
#    f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0  0.632582  0.632005    0.666545   0.667618      0.601913     0.600000
# 1  0.715596  0.720467    0.573302   0.580266      0.951847     0.950000
# 2  0.709559  0.710791    0.563287   0.567816      0.958443     0.950000
# 3  0.698590  0.711599    0.585377   0.600529      0.866095     0.873077
# 4  0.732973  0.731405    0.610222   0.612457      0.917546     0.907692
# 5  0.614426  0.620939    0.558554   0.585034      0.682718     0.661538
#
#         elapsed feature_map_type optimizer  \
# 0  16172.243627            Pauli    cobyla
# 1  13538.573926            Pauli    cobyla
# 2  11312.101276            Pauli    cobyla
# 3  36492.329890            Pauli      spsa
# 4  32556.542017            Pauli      spsa
# 5  34408.853433            Pauli      spsa
#
#                                       objective_vals     Ansatz  \
# 0  [0.9955071123141361, 0.9968499301903374, 0.995...        su2
# 1  [1.0093994267349489, 1.0097192964774158, 0.997...  two_local
# 2  [0.9866457593259174, 0.9892075741769691, 0.986...    n_local
# 3  [0.9952617117278842, 0.9921541356552587, 0.991...        su2
# 4  [1.0136491466111865, 0.9998966158707154, 0.999...  two_local
# 5  [0.999128702107861, 1.0005809021906438, 0.9978...    n_local
#
#    Training time Model  Max Iter  reps
# 0   16172.243627   VQC       100     2
# 1   13538.573926   VQC       100     2
# 2   11312.101276   VQC       100     2
# 3   36492.329890   VQC       100     2
# 4   32556.542017   VQC       100     2
# 5   34408.853433   VQC       100     2

# %%
n = []
#n.append(ast.literal_eval(tot_df.loc[0, "objective_vals"]))
#n
ansatz_list = list(tot_df["Ansatz"].unique())
optim_list = list(tot_df["optimizer"].unique())
ansatz_list, optim_list
# Out:
# (['su2', 'two_local', 'n_local'], ['cobyla', 'spsa'])

# %% [markdown]
# ### Loss Analysis

# %%
def loss_eda(feat_map, col="blue"):
    data = tot_df[tot_df["feature_map_type"] == feat_map]
    fig, axes = plt.subplots(nrows=len(ansatz_list), ncols=len(optim_list), figsize = (28, 16))
    for i in range(len(ansatz_list)):
        for j in range(len(optim_list)):
            use_data = data[(data["Ansatz"] == ansatz_list[i]) & (data["optimizer"] == optim_list[j])].reset_index(drop=True)
            loss_val = ast.literal_eval(use_data.loc[0,"objective_vals"])
            #print(loss_val)
            sns.lineplot(x = range(len(loss_val)), y = loss_val, ax = axes[i,j], color=col)
            ax = axes[i,j]
            ax.set_ylabel("loss", fontsize=10)
            ax.set_xlabel("iteration", fontsize=10)
            ax.set_title("Loss plot using %s and %s"%(ansatz_list[i], optim_list[j]))

# %%
loss_eda("Pauli","red")

# %%
tot_df
# Out:
#    f1_train   f1_test  prec_train  prec_test  recall_train  recall_test  \
# 0  0.632582  0.632005    0.666545   0.667618      0.601913     0.600000
# 1  0.715596  0.720467    0.573302   0.580266      0.951847     0.950000
# 2  0.709559  0.710791    0.563287   0.567816      0.958443     0.950000
# 3  0.698590  0.711599    0.585377   0.600529      0.866095     0.873077
# 4  0.732973  0.731405    0.610222   0.612457      0.917546     0.907692
# 5  0.614426  0.620939    0.558554   0.585034      0.682718     0.661538
#
#         elapsed feature_map_type optimizer  \
# 0  16172.243627            Pauli    cobyla
# 1  13538.573926            Pauli    cobyla
# 2  11312.101276            Pauli    cobyla
# 3  36492.329890            Pauli      spsa
# 4  32556.542017            Pauli      spsa
# 5  34408.853433            Pauli      spsa
#
#                                       objective_vals     Ansatz  \
# 0  [0.9955071123141361, 0.9968499301903374, 0.995...        su2
# 1  [1.0093994267349489, 1.0097192964774158, 0.997...  two_local
# 2  [0.9866457593259174, 0.9892075741769691, 0.986...    n_local
# 3  [0.9952617117278842, 0.9921541356552587, 0.991...        su2
# 4  [1.0136491466111865, 0.9998966158707154, 0.999...  two_local
# 5  [0.999128702107861, 1.0005809021906438, 0.9978...    n_local
#
#    Training time Model  Max Iter  reps
# 0   16172.243627   VQC       100     2
# 1   13538.573926   VQC       100     2
# 2   11312.101276   VQC       100     2
# 3   36492.329890   VQC       100     2
# 4   32556.542017   VQC       100     2
# 5   34408.853433   VQC       100     2

# %% [markdown]
# ## Univariate Analysis

# %%
def box_relation(cat, num):
    plt.figure(figsize=(15,8))
    sns.boxplot(x=cat, y = num, data = tot_df)
    plt.xlabel(cat)
    plt.ylabel(num)
    plt.title("Distribution of %s across %s"%(num, cat))
    plt.show();

# %%
box_relation("Ansatz", "Training time")

# %%
box_relation("Ansatz", "f1_test")

# %%
box_relation("optimizer", "Training time")

# %%
box_relation("optimizer", "f1_test")

# %% [markdown]
# ## Multivariate Analysis

# %%
def conf_mat_create(feat_map, var1, var2, num):
    use_df = tot_df[tot_df["feature_map_type"]==feat_map]
    use_df = use_df[[var1, var2, num]]
    pivot_df = use_df.pivot_table(index = [var1], columns = var2, values=num)
    plt.figure(figsize=(15,10))
    sns.heatmap(pivot_df, annot=True, fmt=".2f", linewidths=.5, cmap="RdBu",)
    plt.title("%s across different %s and %s combos for %s feature map"%(num, var1, var2, feat_map))
    #return pivot_df

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "Training time")

# %%
conf_mat_create("Pauli","optimizer", "Ansatz", "f1_test")

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x="Training time", y="f1_score", data=tot_df, hue = "feature_map_type")
plt.xlabel("Training time")
plt.ylabel("F1 score")
plt.title("F1 score vs Training time")
plt.text(x = 5600, y=0.59,s = "Best Algo", fontdict={"fontweight":"bold"})
plt.legend(loc="best")
plt.show()
