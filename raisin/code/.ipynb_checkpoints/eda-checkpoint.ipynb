# %%
import pandas as pd
import seaborn as sns; sns.set_style("darkgrid")
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import janitor
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_categorical_dtype

# %% [markdown]
# ### Mini data cleaning

# %%
train = pd.read_csv("../data/train.csv").clean_names()
#df

# %%
train
# Out:
#        udi product_id type  air_temperature_k  process_temperature_k  \
# 0     9255     L56434    L              298.3                  309.1
# 1     1562     L48741    L              298.2                  308.4
# 2     1671     L48850    L              298.2                  307.8
# 3     6088     M20947    M              300.9                  310.8
# 4     6670     L53849    L              301.4                  310.5
# ...    ...        ...  ...                ...                    ...
# 7995  5735     L52914    L              302.3                  311.8
# 7996  5192     L52371    L              304.0                  313.2
# 7997  5391     H34804    H              302.8                  312.3
# 7998   861     H30274    H              296.1                  306.9
# 7999  7271     L54450    L              300.2                  310.4
#
#       rotational_speed_rpm  torque_nm  tool_wear_min  target  \
# 0                     1616       31.1            195       0
# ...

# %%
train["target"].value_counts()
# Out:
# 0    7722
# 1     278
# Name: target, dtype: int64

# %%
train["failure_type"].value_counts()
# Out:
# No Failure                  7717
# Heat Dissipation Failure      97
# Power Failure                 75
# Overstrain Failure            65
# Tool Wear Failure             34
# Random Failures               12
# Name: failure_type, dtype: int64

# %%
train[(train["target"] == 1) & (train["failure_type"] == "No Failure")]
# Out:
#        udi product_id type  air_temperature_k  process_temperature_k  \
# 911   1438     H30851    H              298.8                  309.9
# 3408  8507     L55686    L              298.4                  309.6
# 3960  2750     M17609    M              299.7                  309.2
# 4523  4045     M18904    M              301.9                  310.9
# 6801  9016     L56195    L              297.2                  308.1
# 6859  5942     L53121    L              300.6                  310.7
# 7549  5537     M20396    M              302.3                  311.8
#
#       rotational_speed_rpm  torque_nm  tool_wear_min  target failure_type
# 911                   1439       45.2             40       1   No Failure
# 3408                  1710       27.3            163       1   No Failure
# 3960                  1685       28.9            179       1   No Failure
# 4523                  1419       47.7             20       1   No Failure
# ...

# %%
train["type"].value_counts()
# Out:
# L    4776
# M    2422
# H     802
# Name: type, dtype: int64

# %%
train["type"] = train["type"].astype("category")

# %%
train.head()
# Out:
#     udi product_id type  air_temperature_k  process_temperature_k  \
# 0  9255     L56434    L              298.3                  309.1
# 1  1562     L48741    L              298.2                  308.4
# 2  1671     L48850    L              298.2                  307.8
# 3  6088     M20947    M              300.9                  310.8
# 4  6670     L53849    L              301.4                  310.5
#
#    rotational_speed_rpm  torque_nm  tool_wear_min  target failure_type
# 0                  1616       31.1            195       0   No Failure
# 1                  1388       53.8            137       0   No Failure
# 2                  1528       31.1            194       0   No Failure
# 3                  1599       33.0              7       0   No Failure
# 4                  1571       33.9            208       0   No Failure

# %%
train.shape
# Out:
# (8000, 10)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   udi                    8000 non-null   int64
#  1   product_id             8000 non-null   object
#  2   type                   8000 non-null   category
#  3   air_temperature_k      8000 non-null   float64
#  4   process_temperature_k  8000 non-null   float64
#  5   rotational_speed_rpm   8000 non-null   int64
#  6   torque_nm              8000 non-null   float64
#  7   tool_wear_min          8000 non-null   int64
#  8   target                 8000 non-null   int64
#  9   failure_type           8000 non-null   object
# dtypes: category(1), float64(3), int64(4), object(2)
# memory usage: 570.6+ KB

# %%
train_use = train.drop(["udi", "product_id", "failure_type"], axis = 1)
train_use.to_csv("../data/train_new.csv")

# %%
test = pd.read_csv("../data/test.csv")
#test = test.merge(region, how = "left", left_on = "state", right_on = "State Code").clean_names()
#test.info()

# %%
test["type"] = test["type"].astype("category")

# %%
test.head()
# Out:
#     udi product_id type  air_temperature_k  process_temperature_k  \
# 0  6253     L53432    L              300.8                  310.3
# 1  4685     M19544    M              303.6                  311.8
# 2  1732     M16591    M              298.3                  307.9
# 3  4743     L51922    L              303.3                  311.3
# 4  4522     L51701    L              302.4                  310.4
#
#    rotational_speed_rpm  torque_nm  tool_wear_min  target failure_type
# 0                  1538       36.1            198       0   No Failure
# 1                  1421       44.8            101       1   No Failure
# 2                  1485       42.0            117       0   No Failure
# 3                  1592       33.7             14       0   No Failure
# 4                  1865       23.9            129       0   No Failure

# %%
test_use = test.drop(["udi", "product_id", "failure_type"], axis = 1)
test_use.to_csv("../data/test_new.csv")

# %%
test.shape
# Out:
# (2000, 10)

# %%
test["target"].value_counts()
# Out:
# 0    1939
# 1      61
# Name: target, dtype: int64

# %% [markdown]
# ### Univariate analysis

# %%
def cat_eda(var):
    plt.figure(figsize=(15,10))
    sns.countplot(x = var, data = train, hue  = "target")
    plt.show();

# %%
cat_eda("type")

# %%
def num_eda(var):
    plt.figure(figsize=(15,10))
    sns.kdeplot(x = var, data = train, hue  = "target")
    #plt.ylim(0, 500)
    plt.show();

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   udi                    8000 non-null   int64
#  1   product_id             8000 non-null   object
#  2   type                   8000 non-null   category
#  3   air_temperature_k      8000 non-null   float64
#  4   process_temperature_k  8000 non-null   float64
#  5   rotational_speed_rpm   8000 non-null   int64
#  6   torque_nm              8000 non-null   float64
#  7   tool_wear_min          8000 non-null   int64
#  8   target                 8000 non-null   int64
#  9   failure_type           8000 non-null   object
# dtypes: category(1), float64(3), int64(4), object(2)
# memory usage: 570.6+ KB

# %%
num_eda("air_temperature_k")

# %%
num_eda("process_temperature_k")

# %%
num_eda("rotational_speed_rpm")

# %%
num_eda("torque_nm")

# %%
num_eda("tool_wear_min")

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.figure(figsize=(40,20))
sns.pairplot(train_use, hue="target")
plt.show();

# %%
cat_col = []
num_col = []
for col in list(train.columns):
    if is_categorical_dtype(train[col]):
        cat_col.append(col)
    elif is_numeric_dtype(train[col]):
        num_col.append(col)

# %%
num_col, cat_col
# Out:
# (['udi',
#   'air_temperature_k',
#   'process_temperature_k',
#   'rotational_speed_rpm',
#   'torque_nm',
#   'tool_wear_min',
#   'target'],
#  ['type'])

# %%
num_col.remove("target")
num_col.remove("udi")

# %%
num_col, cat_col
# Out:
# (['air_temperature_k',
#   'process_temperature_k',
#   'rotational_speed_rpm',
#   'torque_nm',
#   'tool_wear_min'],
#  ['type'])

# %%
def multiple_cat_num_eda(num, cat):
    fig, axes = plt.subplots(nrows=len(num), ncols=1, figsize = (20, 40))
    for i in range(len(num)):
        for j in range(len(cat)):
          #if var_list[i] != var_list[j]:
            sns.violinplot(x = cat[j], y = num[i], data = train, hue = "target", ax = axes[i])
            ax = axes[i]
            ax.set_ylabel(num[i], fontsize=14)
            ax.set_xlabel(cat[j], fontsize=14)

# %%
multiple_cat_num_eda(num_col, cat_col)
