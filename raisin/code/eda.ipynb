# %%
import pandas as pd
import seaborn as sns; sns.set_style("darkgrid")
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import janitor
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_categorical_dtype

# %% [markdown]
# ### Mini data cleaning

# %%
train = pd.read_csv("../data/train.csv").clean_names()
#df

# %%
train
# Out:
#        area  majoraxislength  minoraxislength  eccentricity  convexarea  \
# 0     80437       449.454581       232.325506      0.856043       84460
# 1     72483       334.417609       282.680889      0.534303       74945
# 2     85739       380.370379       288.256159      0.652452       87052
# 3    182788       621.206763       379.424446      0.791796      188848
# 4     62835       421.169338       191.169862      0.891051       64406
# ..      ...              ...              ...           ...         ...
# 715   48945       269.370411       239.162166      0.460121       51456
# 716   54968       300.954432       234.389570      0.627246       56851
# 717  166654       607.996465       349.658989      0.818083      169060
# 718   28216       245.401295       150.245582      0.790669       30316
# 719   57808       309.971657       241.366511      0.627430       58954
#
#        extent  perimeter   target
# 0    0.674236   1176.305  Kecimen
# 1    0.706180   1052.159  Kecimen
# 2    0.762152   1094.576  Kecimen
# 3    0.733061   1679.075    Besni
# 4    0.786145   1018.553  Kecimen
# ..        ...        ...      ...
# 715  0.711244    872.289  Kecimen
# 716  0.751340    893.644  Kecimen
# 717  0.753518   1574.164    Besni
# 718  0.622293    683.004  Kecimen
# 719  0.710347    911.857  Kecimen
#
# [720 rows x 8 columns]

# %%
train["target"].value_counts()
# Out:
# Besni      364
# Kecimen    356
# Name: target, dtype: int64

# %%
train.head()
# Out:
#      area  majoraxislength  minoraxislength  eccentricity  convexarea  \
# 0   80437       449.454581       232.325506      0.856043       84460
# 1   72483       334.417609       282.680889      0.534303       74945
# 2   85739       380.370379       288.256159      0.652452       87052
# 3  182788       621.206763       379.424446      0.791796      188848
# 4   62835       421.169338       191.169862      0.891051       64406
#
#      extent  perimeter   target
# 0  0.674236   1176.305  Kecimen
# 1  0.706180   1052.159  Kecimen
# 2  0.762152   1094.576  Kecimen
# 3  0.733061   1679.075    Besni
# 4  0.786145   1018.553  Kecimen

# %%
train.shape
# Out:
# (720, 8)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   area             720 non-null    int64
#  1   majoraxislength  720 non-null    float64
#  2   minoraxislength  720 non-null    float64
#  3   eccentricity     720 non-null    float64
#  4   convexarea       720 non-null    int64
#  5   extent           720 non-null    float64
#  6   perimeter        720 non-null    float64
#  7   target           720 non-null    object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 45.1+ KB

# %% [markdown]
# ### Univariate analysis

# %%
def cat_eda(var):
    plt.figure(figsize=(15,10))
    sns.countplot(x = var, data = train, hue  = "target")
    plt.show();

# %%
#cat_eda("type")

# %%
def num_eda(var):
    plt.figure(figsize=(15,10))
    sns.kdeplot(x = var, data = train, hue  = "target")
    #plt.ylim(0, 500)
    plt.show();

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   area             720 non-null    int64
#  1   majoraxislength  720 non-null    float64
#  2   minoraxislength  720 non-null    float64
#  3   eccentricity     720 non-null    float64
#  4   convexarea       720 non-null    int64
#  5   extent           720 non-null    float64
#  6   perimeter        720 non-null    float64
#  7   target           720 non-null    object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 45.1+ KB

# %%
num_eda("area")

# %%
num_eda("majoraxislength")

# %%
num_eda("minoraxislength")

# %%
num_eda("eccentricity")

# %%
num_eda("convexarea")

# %%
num_eda("extent")

# %%
num_eda("perimeter")

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.figure(figsize=(40,20))
sns.pairplot(train, hue="target")
plt.show();

# %%
#cat_col = []
#num_col = []
#for col in list(train.columns):
#    if is_categorical_dtype(train[col]):
#        cat_col.append(col)
#    elif is_numeric_dtype(train[col]):
#        num_col.append(col)

# %%
#num_col, cat_col

# %%
#num_col.remove("target")
#num_col.remove("udi")

# %%
#num_col, cat_col

# %%
#def multiple_cat_num_eda(num, cat):
#    fig, axes = plt.subplots(nrows=len(num), ncols=1, figsize = (20, 40))
#    for i in range(len(num)):
#        for j in range(len(cat)):
#          #if var_list[i] != var_list[j]:
#            sns.violinplot(x = cat[j], y = num[i], data = train, hue = "target", ax = axes[i])
#            ax = axes[i]
#            ax.set_ylabel(num[i], fontsize=14)
#            ax.set_xlabel(cat[j], fontsize=14)

# %%
#multiple_cat_num_eda(num_col, cat_col)
